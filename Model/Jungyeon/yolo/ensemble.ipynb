# %%
import numpy as np # numpy import
import pandas as pd # pandas import
import os # os import
from tqdm import tqdm # 진행상황 확인을 위한 tqdm import

# %%
def extract_rows_by_classes(csv_file, output_file, column_name, class_names):
    # CSV 파일 읽기
    df = pd.read_csv(csv_file)

    # 클래스 이름이 주어진 목록에 포함된 행만 필터링
    filtered_rows = df[df[column_name].isin(class_names)]

    # 결과 저장
    filtered_rows.to_csv(output_file, index=False)

    print(f"추출된 행이 {output_file}에 저장되었습니다.")

# 사용 예시
input_csv = "/data/ephemeral/home/Jungyeon/Yolo/yolo11x_seg_output_no_dup.csv"
output_csv = "/data/ephemeral/home/Jungyeon/Yolo/yolo11x_backhand.csv"

# 추출할 클래스 이름 목록
class_names = ["Trapezium", "Trapezoid", "Capitate", "Hamate", "Scaphoid", "Lunate", "Triquetrum", "Pisiform"]

# 조건을 적용할 열 이름
column_to_filter = "class"

extract_rows_by_classes(input_csv, output_csv, column_to_filter, class_names)
# Out:
# 추출된 행이 /data/ephemeral/home/Jungyeon/Yolo/yolo11x_backhand.csv에 저장되었습니다.

# %%
def csv_ensemble(csv_paths, save_dir, threshold):  # threshold 파라미터 추가
   def decode_rle_to_mask(rle, height, width):
       s = rle.split()
       starts, lengths = [np.asarray(x, dtype=int) for x in (s[0:][::2], s[1:][::2])]
       starts -= 1
       ends = starts + lengths
       img = np.zeros(height * width, dtype=np.uint8)
       
       for lo, hi in zip(starts, ends):
           img[lo:hi] = 1
       
       return img.reshape(height, width)

   def encode_mask_to_rle(mask):
       pixels = mask.flatten()
       pixels = np.concatenate([[0], pixels, [0]])
       runs = np.where(pixels[1:] != pixels[:-1])[0] + 1
       runs[1::2] -= runs[::2]
       return ' '.join(str(x) for x in runs)

   # csv의 기본 column(column이지만 사실 row입니다.. default 8352)
   csv_column = 2304

   csv_data = []
   for path in csv_paths:
       data = pd.read_csv(path)
       csv_data.append(data)

   file_num = len(csv_data)
   filename_and_class = []
   rles = []

   print(f"앙상블할 모델 수: {file_num}, threshold: {threshold}")  # 정보 출력 추가

   for index in tqdm(range(csv_column)):    
       model_rles = []
       for data in csv_data:
           # rle 적용 시 이미지 사이즈는 변경하시면 안됩니다. 기본 test 이미지의 사이즈 그대로 유지하세요!
           if(type(data.iloc[index]['rle']) == float):
               model_rles.append(np.zeros((2048,2048)))
               continue
           model_rles.append(decode_rle_to_mask(data.iloc[index]['rle'],2048,2048))
       
       image = np.zeros((2048,2048))

       for model in model_rles:
           image += model
       
       # threshold 값으로 결정 (threshold의 값은 투표 수입니다!)
       # threshold로 설정된 값보다 크면 1, 작으면 0으로 변경합니다.
       image[image <= threshold] = 0
       image[image > threshold] = 1

       result_image = image

       rles.append(encode_mask_to_rle(result_image))
       filename_and_class.append(f"{csv_data[0].iloc[index]['class']}_{csv_data[0].iloc[index]['image_name']}")

   classes, filename = zip(*[x.split("_") for x in filename_and_class])
   image_name = [os.path.basename(f) for f in filename]

   # 기본 Dataframe의 구조는 image_name, class, rle로 되어있습니다.
   df = pd.DataFrame({
       "image_name": image_name,
       "class": classes,
       "rle": rles,
   })

   # 최종 ensemble output 저장
   df.to_csv(save_dir, index=False)

# %%
csv_paths = ['/data/ephemeral/home/Jungyeon/Yolo/yolo11x_backhand.csv',
             '/data/ephemeral/home/Jungyeon/Yolo/submission_backhand.csv']

# threshold in [2]에서 []의 숫자를 변경하면 투표 임계값을 설정하실 수 있습니다.
for threshold in [1]:
    save_path = f"ensemble_threshold_{threshold}.csv"
    csv_ensemble(csv_paths, save_path, threshold)
# Out:
# 앙상블할 모델 수: 2, threshold: 1
#   0%|          | 0/2304 [00:00<?, ?it/s]
# 100%|██████████| 2304/2304 [04:19<00:00,  8.89it/s]

# %%
import pandas as pd

def update_rle(csv_file, backhand_file, output_file, image_name, class_name):
    # CSV 파일 읽기
    df_input = pd.read_csv(csv_file)
    df_backhand = pd.read_csv(backhand_file)
    
    for image in image_name:
        for cls in class_name:
            mask_bh = (df_backhand['image_name'] == image) & (df_backhand['class'] == cls)
            new_rle = df_backhand.loc[mask_bh, 'rle']
            # 조건에 맞는 행의 rle 값을 수정
            mask_ip = (df_input['image_name'] == image) & (df_input['class'] == cls)
            df_input.loc[mask_ip, 'rle'] = new_rle.values
            print(f"'{image}'와 '{cls}'에 해당하는 rle 값이 '{new_rle}'로 변경되었습니다.")
        

    # 수정된 DataFrame 저장
    df_input.to_csv(output_file, index=False)
    print(f"수정된 파일은 {output_file}에 저장되었습니다.")

# 사용 예시
input_csv = "/data/ephemeral/home/Jungyeon/Yolo/yolo11x_seg_output_no_dup.csv"
backhand_csv = "/data/ephemeral/home/Jungyeon/Yolo/ensemble_threshold_1.csv"
output_csv = "/data/ephemeral/home/Jungyeon/Yolo/ensemble.csv"

target_image_name = []
for root, dirs, files in os.walk("/data/ephemeral/home/data/test/DCM"):
    dirs.sort()
    files.sort()

    target_image_name.extend(file_name for file_name in files)
print(target_image_name)


# 수정할 조건 및 새로운 rle 값
target_class_name = ["Trapezium", "Trapezoid", "Capitate", "Hamate", "Scaphoid", "Lunate", "Triquetrum", "Pisiform"]

update_rle(input_csv, backhand_csv, output_csv, target_image_name, target_class_name)
# Out:
# ['image1661319116107.png', 'image1661319145363.png', 'image1661319356239.png', 'image1661319390106.png', 'image1661320372752.png', 'image1661320397148.png', 'image1661320538919.png', 'image1661320557045.png', 'image1661320671343.png', 'image1661320722689.png', 'image1661320864475.png', 'image1661320892395.png', 'image1661320944318.png', 'image1661320972355.png', 'image1661389291522.png', 'image1661389310383.png', 'image1661389524954.png', 'image1661389553713.png', 'image1661389595277.png', 'image1661389621012.png', 'image1661735854451.png', 'image1661735882043.png', 'image1662340967509.png', 'image1662340984526.png', 'image1662341048902.png', 'image1662341087474.png', 'image1662341167750.png', 'image1662341205574.png', 'image1662341263517.png', 'image1662341292950.png', 'image1662341360854.png', 'image1662341377096.png', 'image1662341616527.png', 'image1662341653233.png', 'image1662341848883.png', 'image1662341889065.png', 'image1662342205281.png', 'image1662342232684.png', 'image1662342284287.png', 'image1662342311850.png', 'image1662342369059.png', 'image1662342396399.png', 'image1662342486105.png', 'image1662342504123.png', 'image1662342557856.png', 'image1662342597802.png', 'image1662342787622.png', 'image1662342803512.png', 'image1662342855916.png', 'image1662342883637.png', 'image1662342925774.png', 'image1662342952534.png', 'image1662343006466.png', 'image1662343045337.png', 'image1662343161641.png', 'image1662343190033.png', 'image1662343340009.png', 'image1662343358428.png', 'image1662344039446.png', 'image1662344065321.png', 'image1662344117299.png', 'image1662344133744.png', 'image1662347647599.png', 'image1662347684401.png', 'image1662512730066.png', 'image1662512750105.png', 'image1662512801013.png', 'image1662512817834.png', 'image1662512859960.png', 'image1662512886928.png', 'image1662512937750.png', 'image1662512967586.png', 'image1662513199334.png', 'image1662513216199.png', 'image1662513667368.png', 'image1662513697452.png', 'image1662513911258.png', 'image1662513938885.png', 'image1662513979006.png', 'image1662514007054.png', 'image1662514085478.png', 'image1662514111809.png', 'image1662514163925.png', 'image1662514202560.png', 'image1662514420730.png', 'image1662514460692.png', 'image1662514615500.png', 'image1662514645874.png', 'image1662514709715.png', 'image1662514750170.png', 'image1662514815967.png', 'image1662514845640.png', 'image1662514907444.png', 'image1662514947169.png', 'image1662515001202.png', 'image1662515031657.png', 'image1662515100899.png', 'image1662515131201.png', 'image1662515481973.png', 'image1662515522722.png', 'image1662515589122.png', 'image1662515616993.png', 'image1662515671457.png', 'image1662515699185.png', 'image1662515804622.png', 'image1662515834348.png', 'image1662515885578.png', 'image1662515915181.png', 'image1663031053384.png', 'image1663031089301.png', 'image1663031192101.png', 'image1663031217356.png', 'image1663031259827.png', 'image1663031285124.png', 'image1663031328120.png', 'image1663031355282.png', 'image1663031512045.png', 'image1663031539970.png', 'image1663031729050.png', 'image1663031757254.png', 'image1663032094569.png', 'image1663032123062.png', 'image1663032200123.png', 'image1663032215672.png', 'image1663032341274.png', 'image1663032378555.png', 'image1663032434284.png', 'image1663032464049.png', 'image1663032787672.png', 'image1663032815373.png', 'image1663033739084.png', 'image1663033766028.png', 'image1663034114127.png', 'image1663034135371.png', 'image1663034183469.png', 'image1663034202366.png', 'image1663034255194.png', 'image1663034294082.png', 'image1663034350052.png', 'image1663034378702.png', 'image1663034430558.png', 'image1663034460436.png', 'image1663035050652.png', 'image1663035076575.png', 'image1663035116382.png', 'image1663035143421.png', 'image1663117163557.png', 'image1663117191552.png', 'image1663117343870.png', 'image1663117371313.png', 'image1663117424196.png', 'image1663117441830.png', 'image1663117541589.png', 'image1663117559768.p ...
# 'image1661319116107.png'와 'Trapezium'에 해당하는 rle 값이 '0    2978613 22 2980661 22 2982709 22 2984757 22 29...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661319116107.png'와 'Trapezoid'에 해당하는 rle 값이 '1    3003206 28 3005254 31 3007302 33 3009350 35 30...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661319116107.png'와 'Capitate'에 해당하는 rle 값이 '2    2945991 21 2948039 21 2950087 21 2952135 21 29...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661319116107.png'와 'Hamate'에 해당하는 rle 값이 '3    2962457 41 2964505 41 2966553 41 2968601 41 29...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661319116107.png'와 'Scaphoid'에 해당하는 rle 값이 '4    3150715 24 3152762 26 3154809 27 3156856 29 31...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661319116107.png'와 'Lunate'에 해당하는 rle 값이 '5    3265469 31 3267517 31 3269565 31 3271613 31 32...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661319116107.png'와 'Triquetrum'에 해당하는 rle 값이 '6    3142713 22 3144759 26 3146805 31 3148851 35 31...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661319116107.png'와 'Pisiform'에 해당하는 rle 값이 '7    3200055 34 3202103 35 3204151 35 3206199 35 32...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661319145363.png'와 'Trapezium'에 해당하는 rle 값이 '8    2823291 31 2825338 34 2827385 36 2829433 37 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661319145363.png'와 'Trapezoid'에 해당하는 rle 값이 '9    2856017 32 2858065 32 2860113 32 2862161 32 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661319145363.png'와 'Capitate'에 해당하는 rle 값이 '10    2806749 21 2808796 25 2810841 31 2812886 36 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661319145363.png'와 'Hamate'에 해당하는 rle 값이 '11    2823041 67 2825089 67 2827137 67 2829185 67 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661319145363.png'와 'Scaphoid'에 해당하는 rle 값이 '12    3003443 24 3005491 24 3007539 24 3009587 24 30...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661319145363.png'와 'Lunate'에 해당하는 rle 값이 '13    3126234 33 3128281 34 3130327 36 3132374 37 31...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661319145363.png'와 'Triquetrum'에 해당하는 rle 값이 '14    2995041 33 2997089 33 2999137 33 3001185 33 30...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661319145363.png'와 'Pisiform'에 해당하는 rle 값이 '15    3068777 40 3070824 41 3072871 42 3074919 42 30...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661319356239.png'와 'Trapezium'에 해당하는 rle 값이 '16    2773830 28 2775878 28 2777926 28 2779974 28 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661319356239.png'와 'Trapezoid'에 해당하는 rle 값이 '17    2782065 33 2784112 38 2786159 41 2788207 42 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661319356239.png'와 'Capitate'에 해당하는 rle 값이 '18    2733027 32 2735075 32 2737123 32 2739171 32 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661319356239.png'와 'Hamate'에 해당하는 rle 값이 '19    2724915 26 2726963 26 2729011 26 2731059 26 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661319356239.png'와 'Scaphoid'에 해당하는 rle 값이 '20    2937749 25 2939797 25 2941845 25 2943893 25 29...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661319356239.png'와 'Lunate'에 해당하는 rle 값이 '21    3052504 47 3054552 47 3056600 47 3058648 47 30...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661319356239.png'와 'Triquetrum'에 해당하는 rle 값이 '22    2929730 22 2931778 22 2933826 22 2935874 22 29...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661319356239.png'와 'Pisiform'에 해당하는 rle 값이 '23    2962496 32 2964544 32 2966592 32 2968640 32 29...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661319390106.png'와 'Trapezium'에 해당하는 rle 값이 '24    2757695 21 2759741 24 2761788 26 2763836 27 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661319390106.png'와 'Trapezoid'에 해당하는 rle 값이 '25    2749438 41 2751486 41 2753534 41 2755582 41 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661319390106.png'와 'Capitate'에 해당하는 rle 값이 '26    2708370 26 2710418 34 2712465 38 2714512 41 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661319390106.png'와 'Hamate'에 해당하는 rle 값이 '27    2691913 28 2693961 28 2696009 28 2698057 28 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661319390106.png'와 'Scaphoid'에 해당하는 rle 값이 '28    2929651 25 2931698 28 2933745 31 2935792 33 29...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661319390106.png'와 'Lunate'에 해당하는 rle 값이 '29    3011465 35 3013513 35 3015561 35 3017609 35 30...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661319390106.png'와 'Triquetrum'에 해당하는 rle 값이 '30    2880314 23 2882362 23 2884410 23 2886458 23 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661319390106.png'와 'Pisiform'에 해당하는 rle 값이 '31    2913077 35 2915125 35 2917173 35 2919221 35 29...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320372752.png'와 'Trapezium'에 해당하는 rle 값이 '32    2749267 32 2751315 32 2753363 32 2755411 32 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320372752.png'와 'Trapezoid'에 해당하는 rle 값이 '33    2782082 39 2784128 43 2786175 46 2788223 49 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320372752.png'와 'Capitate'에 해당하는 rle 값이 '34    2765791 44 2767836 50 2769879 57 2771924 61 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320372752.png'와 'Hamate'에 해당하는 rle 값이 '35    2774035 58 2776083 58 2778131 58 2780179 58 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320372752.png'와 'Scaphoid'에 해당하는 rle 값이 '36    2913173 26 2915221 26 2917269 26 2919317 26 29...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320372752.png'와 'Lunate'에 해당하는 rle 값이 '37    3011545 38 3013593 38 3015641 38 3017689 38 30...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320372752.png'와 'Triquetrum'에 해당하는 rle 값이 '38    2946117 29 2948165 29 2950213 29 2952261 29 29...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320372752.png'와 'Pisiform'에 해당하는 rle 값이 '39    3003450 29 3005497 31 3007545 33 3009593 34 30...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320397148.png'와 'Trapezium'에 해당하는 rle 값이 '40    2798708 34 2800756 34 2802804 34 2804852 34 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320397148.png'와 'Trapezoid'에 해당하는 rle 값이 '41    2806837 46 2808885 46 2810933 46 2812981 46 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320397148.png'와 'Capitate'에 해당하는 rle 값이 '42    2798539 52 2800587 60 2802635 63 2804683 65 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320397148.png'와 'Hamate'에 해당하는 rle 값이 '43    2814874 58 2816922 58 2818970 58 2821018 58 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320397148.png'와 'Scaphoid'에 해당하는 rle 값이 '44    2962484 30 2964532 30 2966580 30 2968628 30 29...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320397148.png'와 'Lunate'에 해당하는 rle 값이 '45    3044324 27 3046372 27 3048420 27 3050468 27 30...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320397148.png'와 'Triquetrum'에 해당하는 rle 값이 '46    2986882 32 2988930 32 2990978 32 2993026 32 29...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320397148.png'와 'Pisiform'에 해당하는 rle 값이 '47    3019670 30 3021718 30 3023766 30 3025814 30 30...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320538919.png'와 'Trapezium'에 해당하는 rle 값이 '48    2896682 32 2898730 32 2900778 32 2902826 32 29...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320538919.png'와 'Trapezoid'에 해당하는 rle 값이 '49    2904915 27 2906963 29 2909010 32 2911057 34 29...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320538919.png'와 'Capitate'에 해당하는 rle 값이 '50    2896869 28 2898917 28 2900965 28 2903013 28 29...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320538919.png'와 'Hamate'에 해당하는 rle 값이 '51    2937879 84 2939927 84 2941975 84 2944023 84 29...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320538919.png'와 'Scaphoid'에 해당하는 rle 값이 '52    3150707 32 3152755 32 3154803 32 3156851 32 31...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320538919.png'와 'Lunate'에 해당하는 rle 값이 '53    3265497 36 3267545 36 3269593 36 3271641 36 32...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320538919.png'와 'Triquetrum'에 해당하는 rle 값이 '54    3077246 21 3079294 21 3081342 21 3083390 21 30...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320538919.png'와 'Pisiform'에 해당하는 rle 값이 '55    3134575 34 3136620 37 3138666 39 3140713 40 31...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320557045.png'와 'Trapezium'에 해당하는 rle 값이 '56    2880655 29 2882703 29 2884751 29 2886799 29 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320557045.png'와 'Trapezoid'에 해당하는 rle 값이 '57    2913342 65 2915388 68 2917434 72 2919481 74 29...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320557045.png'와 'Capitate'에 해당하는 rle 값이 '58    2896827 34 2898875 34 2900923 34 2902971 34 29...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320557045.png'와 'Hamate'에 해당하는 rle 값이 '59    2954090 81 2956138 81 2958186 81 2960234 81 29...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320557045.png'와 'Scaphoid'에 해당하는 rle 값이 '60    3150926 37 3152974 37 3155022 37 3157070 37 31...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320557045.png'와 'Lunate'에 해당하는 rle 값이 '61    3265482 40 3267530 40 3269578 40 3271626 40 32...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320557045.png'와 'Triquetrum'에 해당하는 rle 값이 '62    3167060 33 3169108 33 3171156 33 3173204 33 31...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320557045.png'와 'Pisiform'에 해당하는 rle 값이 '63    3232626 37 3234674 37 3236722 37 3238770 37 32...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320671343.png'와 'Trapezium'에 해당하는 rle 값이 '64    2954062 27 2956109 30 2958155 35 2960202 39 29...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320671343.png'와 'Trapezoid'에 해당하는 rle 값이 '65    2978682 36 2980730 36 2982778 36 2984826 36 29...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320671343.png'와 'Capitate'에 해당하는 rle 값이 '66    2929656 36 2931704 36 2933752 36 2935800 36 29...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320671343.png'와 'Hamate'에 해당하는 rle 값이 '67    2937909 65 2939956 67 2942003 69 2944051 69 29...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320671343.png'와 'Scaphoid'에 해당하는 rle 값이 '68    3117985 24 3120033 24 3122081 24 3124129 24 31...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320671343.png'와 'Lunate'에 해당하는 rle 값이 '69    3224565 29 3226613 29 3228661 29 3230709 29 32...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320671343.png'와 'Triquetrum'에 해당하는 rle 값이 '70    3134568 25 3136616 25 3138664 25 3140712 25 31...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320671343.png'와 'Pisiform'에 해당하는 rle 값이 '71    3200091 31 3202139 31 3204187 31 3206235 31 32...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320722689.png'와 'Trapezium'에 해당하는 rle 값이 '72    2790480 22 2792528 22 2794576 22 2796624 22 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320722689.png'와 'Trapezoid'에 해당하는 rle 값이 '73    2823166 48 2825214 48 2827262 48 2829310 48 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320722689.png'와 'Capitate'에 해당하는 rle 값이 '74    2798472 23 2800520 27 2802568 30 2804616 31 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320722689.png'와 'Hamate'에 해당하는 rle 값이 '75    2814779 72 2816827 72 2818875 72 2820923 72 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320722689.png'와 'Scaphoid'에 해당하는 rle 값이 '76    2962421 31 2964469 31 2966517 31 2968565 31 29...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320722689.png'와 'Lunate'에 해당하는 rle 값이 '77    3109788 33 3111836 33 3113884 33 3115932 33 31...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320722689.png'와 'Triquetrum'에 해당하는 rle 값이 '78    3011376 22 3013423 24 3015470 26 3017517 28 30...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320722689.png'와 'Pisiform'에 해당하는 rle 값이 '79    3060538 45 3062586 47 3064634 48 3066682 50 30...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320864475.png'와 'Trapezium'에 해당하는 rle 값이 '80    2732867 27 2734915 27 2736963 27 2739011 27 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320864475.png'와 'Trapezoid'에 해당하는 rle 값이 '81    2741110 43 2743158 45 2745206 47 2747254 48 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320864475.png'와 'Capitate'에 해당하는 rle 값이 '82    2683884 32 2685929 36 2687973 41 2690020 43 26...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320864475.png'와 'Hamate'에 해당하는 rle 값이 '83    2700303 69 2702351 69 2704399 69 2706447 69 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320864475.png'와 'Scaphoid'에 해당하는 rle 값이 '84    2880400 30 2882448 30 2884496 30 2886544 30 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320864475.png'와 'Lunate'에 해당하는 rle 값이 '85    2978784 37 2980831 40 2982878 42 2984926 44 29...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320864475.png'와 'Triquetrum'에 해당하는 rle 값이 '86    2888780 27 2890825 32 2892871 35 2894916 40 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320864475.png'와 'Pisiform'에 해당하는 rle 값이 '87    2937924 25 2939971 27 2942018 28 2944065 30 29...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320892395.png'와 'Trapezium'에 해당하는 rle 값이 '88    2741339 25 2743385 28 2745431 31 2747477 34 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320892395.png'와 'Trapezoid'에 해당하는 rle 값이 '89    2741268 38 2743316 38 2745364 38 2747412 38 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320892395.png'와 'Capitate'에 해당하는 rle 값이 '90    2716584 39 2718631 43 2720679 46 2722727 47 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320892395.png'와 'Hamate'에 해당하는 rle 값이 '91    2732899 66 2734947 66 2736995 66 2739043 66 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320892395.png'와 'Scaphoid'에 해당하는 rle 값이 '92    2888715 31 2890763 31 2892811 31 2894859 31 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320892395.png'와 'Lunate'에 해당하는 rle 값이 '93    2995114 36 2997161 37 2999207 40 3001255 40 30...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320892395.png'와 'Triquetrum'에 해당하는 rle 값이 '94    2904914 23 2906962 23 2909010 23 2911058 23 29...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320892395.png'와 'Pisiform'에 해당하는 rle 값이 '95    2945896 25 2947944 25 2949992 25 2952040 25 29...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320944318.png'와 'Trapezium'에 해당하는 rle 값이 '96    2773827 27 2775875 27 2777923 27 2779971 27 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320944318.png'와 'Trapezoid'에 해당하는 rle 값이 '97    2782071 51 2784119 51 2786167 51 2788215 51 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320944318.png'와 'Capitate'에 해당하는 rle 값이 '98    2741232 35 2743280 35 2745328 35 2747376 35 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320944318.png'와 'Hamate'에 해당하는 rle 값이 '99    2757665 55 2759713 55 2761761 55 2763809 55 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320944318.png'와 'Scaphoid'에 해당하는 rle 값이 '100    2962315 35 2964363 35 2966411 35 2968459 35 29...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320944318.png'와 'Lunate'에 해당하는 rle 값이 '101    3044327 32 3046375 32 3048423 32 3050471 32 30...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320944318.png'와 'Triquetrum'에 해당하는 rle 값이 '102    2946128 31 2948176 31 2950224 31 2952272 31 29...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320944318.png'와 'Pisiform'에 해당하는 rle 값이 '103    2995264 32 2997312 33 2999360 34 3001408 35 30...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320972355.png'와 'Trapezium'에 해당하는 rle 값이 '104    2667614 27 2669662 27 2671710 27 2673758 27 26...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320972355.png'와 'Trapezoid'에 해당하는 rle 값이 '105    2651169 37 2653217 37 2655265 37 2657313 37 26...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320972355.png'와 'Capitate'에 해당하는 rle 값이 '106    2626475 43 2628523 45 2630571 46 2632619 46 26...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320972355.png'와 'Hamate'에 해당하는 rle 값이 '107    2642796 59 2644844 60 2646892 60 2648940 60 26...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320972355.png'와 'Scaphoid'에 해당하는 rle 값이 '108    2847747 6 2847765 37 2849795 6 2849813 37 2851...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320972355.png'와 'Lunate'에 해당하는 rle 값이 '109    2937776 38 2939824 38 2941872 38 2943920 38 29...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320972355.png'와 'Triquetrum'에 해당하는 rle 값이 '110    2831191 23 2833238 26 2835285 28 2837331 32 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661320972355.png'와 'Pisiform'에 해당하는 rle 값이 '111    2872160 36 2874208 36 2876256 36 2878304 36 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661389291522.png'와 'Trapezium'에 해당하는 rle 값이 '112    2888575 33 2890623 33 2892671 33 2894719 33 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661389291522.png'와 'Trapezoid'에 해당하는 rle 값이 '113    2905006 45 2907054 51 2909102 54 2911150 56 29...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661389291522.png'와 'Capitate'에 해당하는 rle 값이 '114    2855983 36 2858028 41 2860075 42 2862123 42 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661389291522.png'와 'Hamate'에 해당하는 rle 값이 '115    2864230 48 2866277 50 2868324 52 2870372 53 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661389291522.png'와 'Scaphoid'에 해당하는 rle 값이 '116    3060688 30 3062736 30 3064784 30 3066832 30 30...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661389291522.png'와 'Lunate'에 해당하는 rle 값이 '117    3183646 35 3185694 35 3187742 35 3189790 35 31...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661389291522.png'와 'Triquetrum'에 해당하는 rle 값이 '118    3077274 21 3079319 25 3081364 29 3083410 32 30...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661389291522.png'와 'Pisiform'에 해당하는 rle 값이 '119    3118198 35 3120245 36 3122292 37 3124339 38 31...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661389310383.png'와 'Trapezium'에 해당하는 rle 값이 '120    2831446 31 2833494 31 2835542 31 2837590 31 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661389310383.png'와 'Trapezoid'에 해당하는 rle 값이 '121    2839561 52 2841609 52 2843657 52 2845705 52 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661389310383.png'와 'Capitate'에 해당하는 rle 값이 '122    2790299 37 2792347 42 2794395 46 2796443 48 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661389310383.png'와 'Hamate'에 해당하는 rle 값이 '123    2814805 71 2816851 73 2818898 74 2820945 75 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661389310383.png'와 'Scaphoid'에 해당하는 rle 값이 '124    3003395 35 3005443 35 3007491 35 3009539 35 30...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661389310383.png'와 'Lunate'에 해당하는 rle 값이 '125    3109803 36 3111851 36 3113899 36 3115947 36 31...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661389310383.png'와 'Triquetrum'에 해당하는 rle 값이 '126    3011398 23 3013446 23 3015494 23 3017542 23 30...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661389310383.png'와 'Pisiform'에 해당하는 rle 값이 '127    3052381 35 3054429 36 3056477 36 3058525 36 30...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661389524954.png'와 'Trapezium'에 해당하는 rle 값이 '128    2782017 31 2784065 31 2786113 31 2788161 31 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661389524954.png'와 'Trapezoid'에 해당하는 rle 값이 '129    2831202 33 2833250 33 2835298 33 2837346 33 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661389524954.png'와 'Capitate'에 해당하는 rle 값이 '130    2790383 27 2792431 27 2794479 27 2796527 27 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661389524954.png'와 'Hamate'에 해당하는 rle 값이 '131    2782240 22 2782272 31 2784287 23 2784319 32 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661389524954.png'와 'Scaphoid'에 해당하는 rle 값이 '132    2986889 27 2988937 27 2990985 27 2993033 27 29...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661389524954.png'와 'Lunate'에 해당하는 rle 값이 '133    3126228 44 3128276 44 3130324 44 3132372 44 31...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661389524954.png'와 'Triquetrum'에 해당하는 rle 값이 '134    2995287 31 2997335 31 2999383 31 3001431 31 30...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661389524954.png'와 'Pisiform'에 해당하는 rle 값이 '135    3052616 36 3054664 36 3056712 36 3058760 36 30...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661389553713.png'와 'Trapezium'에 해당하는 rle 값이 '136    2823250 32 2825298 32 2827346 32 2829394 32 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661389553713.png'와 'Trapezoid'에 해당하는 rle 값이 '137    2864153 47 2866201 47 2868249 47 2870297 47 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661389553713.png'와 'Capitate'에 해당하는 rle 값이 '138    2814877 24 2816925 29 2818973 35 2821021 37 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661389553713.png'와 'Hamate'에 해당하는 rle 값이 '139    2798405 47 2800453 47 2802501 47 2804549 47 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661389553713.png'와 'Scaphoid'에 해당하는 rle 값이 '140    3003398 24 3005446 24 3007494 24 3009542 24 30...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661389553713.png'와 'Lunate'에 해당하는 rle 값이 '141    3134379 37 3136427 37 3138475 37 3140523 37 31...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661389553713.png'와 'Triquetrum'에 해당하는 rle 값이 '142    3027762 35 3029810 35 3031858 35 3033906 35 30...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661389553713.png'와 'Pisiform'에 해당하는 rle 값이 '143    3076932 36 3078979 39 3081026 40 3083073 42 30...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661389595277.png'와 'Trapezium'에 해당하는 rle 값이 '144    2708380 22 2710428 22 2712476 22 2714524 22 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661389595277.png'와 'Trapezoid'에 해당하는 rle 값이 '145    2700232 35 2702280 38 2704328 40 2706376 41 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661389595277.png'와 'Capitate'에 해당하는 rle 값이 '146    2651199 34 2653247 34 2655295 34 2657343 34 26...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661389595277.png'와 'Hamate'에 해당하는 rle 값이 '147    2659434 62 2661481 64 2663529 65 2665577 66 26...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661389595277.png'와 'Scaphoid'에 해당하는 rle 값이 '148    2831338 33 2833386 33 2835434 33 2837482 33 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661389595277.png'와 'Lunate'에 해당하는 rle 값이 '149    2921517 32 2923565 32 2925613 32 2927661 32 29...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661389595277.png'와 'Triquetrum'에 해당하는 rle 값이 '150    2839706 21 2841754 21 2843802 21 2845850 21 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661389595277.png'와 'Pisiform'에 해당하는 rle 값이 '151    2921618 34 2923666 34 2925714 34 2927762 34 29...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661389621012.png'와 'Trapezium'에 해당하는 rle 값이 '152    2724937 29 2726985 29 2729033 29 2731081 29 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661389621012.png'와 'Trapezoid'에 해당하는 rle 값이 '153    2716689 32 2718735 34 2720783 34 2722830 35 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661389621012.png'와 'Capitate'에 해당하는 rle 값이 '154    2659215 42 2661263 42 2663311 42 2665359 42 26...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661389621012.png'와 'Hamate'에 해당하는 rle 값이 '155    2675542 32 2677588 52 2679635 61 2681683 65 26...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661389621012.png'와 'Scaphoid'에 해당하는 rle 값이 '156    2839545 23 2841593 23 2843641 23 2845689 23 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661389621012.png'와 'Lunate'에 해당하는 rle 값이 '157    2937748 32 2939796 32 2941844 32 2943892 32 29...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661389621012.png'와 'Triquetrum'에 해당하는 rle 값이 '158    2831175 16 2833223 16 2835271 16 2837319 16 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661389621012.png'와 'Pisiform'에 해당하는 rle 값이 '159    2896709 40 2898757 40 2900805 40 2902853 40 29...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661735854451.png'와 'Trapezium'에 해당하는 rle 값이 '160    2790252 26 2792299 29 2794346 31 2796393 33 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661735854451.png'와 'Trapezoid'에 해당하는 rle 값이 '161    2814860 31 2816908 31 2818956 31 2821004 31 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661735854451.png'와 'Capitate'에 해당하는 rle 값이 '162    2765845 30 2767893 30 2769941 30 2771989 30 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661735854451.png'와 'Hamate'에 해당하는 rle 값이 '163    2798657 13 2798698 26 2800705 11 2800742 30 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661735854451.png'와 'Scaphoid'에 해당하는 rle 값이 '164    2945975 33 2948023 33 2950071 33 2952119 33 29...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661735854451.png'와 'Lunate'에 해당하는 rle 값이 '165    3052544 38 3054592 38 3056640 39 3058688 39 30...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661735854451.png'와 'Triquetrum'에 해당하는 rle 값이 '166    3011694 27 3013742 27 3015790 27 3017838 27 30...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661735854451.png'와 'Pisiform'에 해당하는 rle 값이 '167    3036262 33 3038309 35 3040356 36 3042404 36 30...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661735882043.png'와 'Trapezium'에 해당하는 rle 값이 '168    2765878 32 2767926 32 2769974 32 2772022 32 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661735882043.png'와 'Trapezoid'에 해당하는 rle 값이 '169    2790409 35 2792457 35 2794505 35 2796553 35 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661735882043.png'와 'Capitate'에 해당하는 rle 값이 '170    2732940 26 2734986 29 2737031 33 2739077 36 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661735882043.png'와 'Hamate'에 해당하는 rle 값이 '171    2741058 24 2743104 26 2745151 27 2747198 28 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661735882043.png'와 'Scaphoid'에 해당하는 rle 값이 '172    2913256 30 2915304 30 2917352 30 2919400 30 29...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661735882043.png'와 'Lunate'에 해당하는 rle 값이 '173    3003283 33 3005331 33 3007379 33 3009427 33 30...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661735882043.png'와 'Triquetrum'에 해당하는 rle 값이 '174    2954035 25 2956083 25 2958131 25 2960179 25 29...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1661735882043.png'와 'Pisiform'에 해당하는 rle 값이 '175    3003206 29 3005254 29 3007302 29 3009350 29 30...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662340967509.png'와 'Trapezium'에 해당하는 rle 값이 '176    2749298 35 2751346 35 2753394 35 2755442 35 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662340967509.png'와 'Trapezoid'에 해당하는 rle 값이 '177    2782139 40 2784187 40 2786235 41 2788283 42 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662340967509.png'와 'Capitate'에 해당하는 rle 값이 '178    2741301 25 2743349 25 2745397 25 2747445 25 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662340967509.png'와 'Hamate'에 해당하는 rle 값이 '179    2757761 36 2759809 37 2761857 38 2763905 38 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662340967509.png'와 'Scaphoid'에 해당하는 rle 값이 '180    2929621 13 2931669 13 2933717 13 2935765 13 29...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662340967509.png'와 'Lunate'에 해당하는 rle 값이 '181    3093527 1 3093548 20 3095573 3 3095596 22 3097...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662340967509.png'와 'Triquetrum'에 해당하는 rle 값이 '182    2954391 34 2956439 34 2958487 34 2960535 34 29...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662340967509.png'와 'Pisiform'에 해당하는 rle 값이 '183    3019901 37 3021949 37 3023997 37 3026045 37 30...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662340984526.png'와 'Trapezium'에 해당하는 rle 값이 '184    2798676 35 2800724 35 2802772 35 2804820 35 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662340984526.png'와 'Trapezoid'에 해당하는 rle 값이 '185    2831367 47 2833413 49 2835460 50 2837506 52 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662340984526.png'와 'Capitate'에 해당하는 rle 값이 '186    2806686 35 2808733 44 2810780 49 2812823 57 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662340984526.png'와 'Hamate'에 해당하는 rle 값이 '187    2814802 37 2816850 37 2818898 37 2820946 37 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662340984526.png'와 'Scaphoid'에 해당하는 rle 값이 '188    3001359 1 3003405 10 3005452 15 3005468 14 300...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662340984526.png'와 'Lunate'에 해당하는 rle 값이 '189    3142574 31 3144622 31 3146670 31 3148718 31 31...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662340984526.png'와 'Triquetrum'에 해당하는 rle 값이 '190    3019581 30 3021629 30 3023677 30 3025725 30 30...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662340984526.png'와 'Pisiform'에 해당하는 rle 값이 '191    3085139 33 3087186 34 3089232 36 3091279 37 30...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341048902.png'와 'Trapezium'에 해당하는 rle 값이 '192    2577250 28 2579298 28 2581346 28 2583394 28 25...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341048902.png'와 'Trapezoid'에 해당하는 rle 값이 '193    2593683 30 2595731 30 2597779 30 2599827 30 26...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341048902.png'와 'Capitate'에 해당하는 rle 값이 '194    2577410 30 2579450 40 2581491 49 2583536 54 25...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341048902.png'와 'Hamate'에 해당하는 rle 값이 '195    2593829 56 2595877 56 2597925 56 2599973 56 26...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341048902.png'와 'Scaphoid'에 해당하는 rle 값이 '196    2741151 38 2743199 38 2745247 38 2747295 38 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341048902.png'와 'Lunate'에 해당하는 rle 값이 '197    2864114 30 2866162 30 2868210 30 2870258 30 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341048902.png'와 'Triquetrum'에 해당하는 rle 값이 '198    2774108 28 2776156 28 2778204 28 2780252 28 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341048902.png'와 'Pisiform'에 해당하는 rle 값이 '199    2815056 28 2817104 29 2819151 31 2821198 33 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341087474.png'와 'Trapezium'에 해당하는 rle 값이 '200    2651254 27 2653302 27 2655350 27 2657398 27 26...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341087474.png'와 'Trapezoid'에 해당하는 rle 값이 '201    2667575 38 2669623 38 2671671 38 2673719 38 26...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341087474.png'와 'Capitate'에 해당하는 rle 값이 '202    2651089 28 2653137 28 2655185 28 2657233 28 26...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341087474.png'와 'Hamate'에 해당하는 rle 값이 '203    2683794 54 2685842 55 2687890 57 2689938 58 26...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341087474.png'와 'Scaphoid'에 해당하는 rle 값이 '204    2815030 30 2817078 30 2819126 30 2821174 30 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341087474.png'와 'Lunate'에 해당하는 rle 값이 '205    2946017 33 2948065 33 2950113 33 2952161 33 29...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341087474.png'와 'Triquetrum'에 해당하는 rle 값이 '206    2864000 30 2866048 30 2868096 30 2870144 30 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341087474.png'와 'Pisiform'에 해당하는 rle 값이 '207    2896799 29 2898845 31 2900892 32 2902939 33 29...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341167750.png'와 'Trapezium'에 해당하는 rle 값이 '208    2732895 23 2734942 25 2736989 26 2739036 27 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341167750.png'와 'Trapezoid'에 해당하는 rle 값이 '209    2765696 34 2767744 34 2769792 34 2771840 34 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341167750.png'와 'Capitate'에 해당하는 rle 값이 '210    2749427 33 2751475 33 2753523 33 2755571 33 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341167750.png'와 'Hamate'에 해당하는 rle 값이 '211    2765852 52 2767900 55 2769947 60 2771995 60 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341167750.png'와 'Scaphoid'에 해당하는 rle 값이 '212    2921360 27 2923407 30 2925454 32 2927500 35 29...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341167750.png'와 'Lunate'에 해당하는 rle 값이 '213    3011566 28 3013614 28 3015662 28 3017710 28 30...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341167750.png'와 'Triquetrum'에 해당하는 rle 값이 '214    2937932 29 2939980 29 2942028 29 2944076 29 29...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341167750.png'와 'Pisiform'에 해당하는 rle 값이 '215    3003453 23 3005500 27 3007548 28 3009596 28 30...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341205574.png'와 'Trapezium'에 해당하는 rle 값이 '216    2806924 25 2808972 25 2811020 25 2813068 25 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341205574.png'와 'Trapezoid'에 해당하는 rle 값이 '217    2823262 29 2825310 29 2827358 29 2829406 29 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341205574.png'와 'Capitate'에 해당하는 rle 값이 '218    2823131 32 2825179 32 2827227 32 2829275 32 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341205574.png'와 'Hamate'에 해당하는 rle 값이 '219    2855850 54 2857891 63 2859938 65 2861986 66 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341205574.png'와 'Scaphoid'에 해당하는 rle 값이 '220    2987089 29 2989137 29 2991185 29 2993233 29 29...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341205574.png'와 'Lunate'에 해당하는 rle 값이 '221    3101685 23 3103733 23 3105781 23 3107829 23 31...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341205574.png'와 'Triquetrum'에 해당하는 rle 값이 '222    3019665 33 3021713 33 3023761 33 3025809 33 30...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341205574.png'와 'Pisiform'에 해당하는 rle 값이 '223    3101604 35 3103652 35 3105700 35 3107748 35 31...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341263517.png'와 'Trapezium'에 해당하는 rle 값이 '224    2904929 33 2906977 33 2909025 33 2911073 33 29...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341263517.png'와 'Trapezoid'에 해당하는 rle 값이 '225    2929567 28 2931615 31 2933663 33 2935711 34 29...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341263517.png'와 'Capitate'에 해당하는 rle 값이 '226    2905120 26 2907165 30 2909208 36 2911252 41 29...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341263517.png'와 'Hamate'에 해당하는 rle 값이 '227    2962510 71 2964558 71 2966606 71 2968654 71 29...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341263517.png'와 'Scaphoid'에 해당하는 rle 값이 '228    3109816 15 3111864 16 3113912 16 3115960 16 31...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341263517.png'와 'Lunate'에 해당하는 rle 값이 '229    3265525 55 3267573 55 3269621 55 3271669 55 32...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341263517.png'와 'Triquetrum'에 해당하는 rle 값이 '230    3159179 34 3161227 34 3163275 34 3165323 34 31...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341263517.png'와 'Pisiform'에 해당하는 rle 값이 '231    3257468 38 3259516 38 3261564 38 3263612 38 32...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341292950.png'와 'Trapezium'에 해당하는 rle 값이 '232    2790561 35 2792609 35 2794657 35 2796705 35 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341292950.png'와 'Trapezoid'에 해당하는 rle 값이 '233    2806893 30 2808941 30 2810989 30 2813037 30 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341292950.png'와 'Capitate'에 해당하는 rle 값이 '234    2831332 57 2833380 57 2835428 57 2837476 57 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341292950.png'와 'Hamate'에 해당하는 rle 값이 '235    2888620 51 2890668 51 2892716 51 2894764 51 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341292950.png'와 'Scaphoid'에 해당하는 rle 값이 '236    3003497 14 3005545 14 3007593 14 3009641 14 30...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341292950.png'와 'Lunate'에 해당하는 rle 값이 '237    3159057 46 3161105 46 3163153 46 3165201 46 31...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341292950.png'와 'Triquetrum'에 해당하는 rle 값이 '238    3085188 33 3087236 33 3089284 33 3091332 33 30...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341292950.png'와 'Pisiform'에 해당하는 rle 값이 '239    3175304 51 3177352 51 3179400 51 3181448 51 31...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341360854.png'와 'Trapezium'에 해당하는 rle 값이 '240    2749304 25 2751351 27 2753398 30 2755445 32 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341360854.png'와 'Trapezoid'에 해당하는 rle 값이 '241    2732960 36 2735008 36 2737056 36 2739104 36 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341360854.png'와 'Capitate'에 해당하는 rle 값이 '242    2692124 38 2694172 38 2696220 38 2698268 38 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341360854.png'와 'Hamate'에 해당하는 rle 값이 '243    2700365 63 2702413 63 2704461 63 2706509 63 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341360854.png'와 'Scaphoid'에 해당하는 rle 값이 '244    2880470 19 2882516 22 2884562 24 2886608 28 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341360854.png'와 'Lunate'에 해당하는 rle 값이 '245    2995240 29 2997288 29 2999336 29 3001384 29 30...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341360854.png'와 'Triquetrum'에 해당하는 rle 값이 '246    2888834 31 2890882 31 2892930 31 2894978 31 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341360854.png'와 'Pisiform'에 해당하는 rle 값이 '247    2921588 32 2923636 32 2925684 32 2927732 32 29...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341377096.png'와 'Trapezium'에 해당하는 rle 값이 '248    2733180 25 2735228 25 2737276 25 2739324 25 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341377096.png'와 'Trapezoid'에 해당하는 rle 값이 '249    2749511 32 2751559 32 2753607 32 2755655 32 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341377096.png'와 'Capitate'에 해당하는 rle 값이 '250    2716623 39 2718671 39 2720719 39 2722767 39 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341377096.png'와 'Hamate'에 해당하는 rle 값이 '251    2724740 59 2726788 59 2728836 59 2730884 59 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341377096.png'와 'Scaphoid'에 해당하는 rle 값이 '252    2888746 31 2890794 31 2892842 31 2894890 31 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341377096.png'와 'Lunate'에 해당하는 rle 값이 '253    3019726 43 3021774 43 3023822 43 3025870 43 30...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341377096.png'와 'Triquetrum'에 해당하는 rle 값이 '254    2913141 25 2915189 25 2917237 25 2919285 25 29...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341377096.png'와 'Pisiform'에 해당하는 rle 값이 '255    2962320 36 2964367 38 2966413 40 2968460 41 29...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341616527.png'와 'Trapezium'에 해당하는 rle 값이 '256    2798391 31 2800439 31 2802487 31 2804535 31 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341616527.png'와 'Trapezoid'에 해당하는 rle 값이 '257    2839400 48 2841447 51 2843493 55 2845541 56 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341616527.png'와 'Capitate'에 해당하는 rle 값이 '258    2831330 47 2833363 62 2835405 68 2837451 70 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341616527.png'와 'Hamate'에 해당하는 rle 값이 '259    2864156 75 2866203 77 2868249 80 2870296 81 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341616527.png'와 'Scaphoid'에 해당하는 rle 값이 '260    3011442 27 3013490 27 3015538 27 3017586 27 30...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341616527.png'와 'Lunate'에 해당하는 rle 값이 '261    3183577 30 3185625 30 3187673 30 3189721 30 31...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341616527.png'와 'Triquetrum'에 해당하는 rle 값이 '262    3060808 33 3062856 33 3064904 33 3066952 33 30...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341616527.png'와 'Pisiform'에 해당하는 rle 값이 '263    3118124 28 3120172 28 3122220 28 3124268 28 31...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341653233.png'와 'Trapezium'에 해당하는 rle 값이 '264    2798714 30 2800761 33 2802808 35 2804856 37 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341653233.png'와 'Trapezoid'에 해당하는 rle 값이 '265    2790459 36 2792507 36 2794555 36 2796603 36 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341653233.png'와 'Capitate'에 해당하는 rle 값이 '266    2765750 52 2767798 52 2769846 52 2771894 52 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341653233.png'와 'Hamate'에 해당하는 rle 값이 '267    2798429 75 2800477 76 2802525 77 2804573 78 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341653233.png'와 'Scaphoid'에 해당하는 rle 값이 '268    2987052 33 2989100 33 2991148 33 2993196 33 29...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341653233.png'와 'Lunate'에 해당하는 rle 값이 '269    3134419 29 3136466 31 3138513 32 3140560 33 31...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341653233.png'와 'Triquetrum'에 해당하는 rle 값이 '270    3027804 32 3029852 32 3031900 32 3033948 32 30...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341653233.png'와 'Pisiform'에 해당하는 rle 값이 '271    3093371 35 3095419 35 3097467 35 3099515 35 31...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341848883.png'와 'Trapezium'에 해당하는 rle 값이 '272    2659161 23 2661209 23 2663257 23 2665305 23 26...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341848883.png'와 'Trapezoid'에 해당하는 rle 값이 '273    2683787 58 2685835 59 2687883 61 2689931 62 26...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341848883.png'와 'Capitate'에 해당하는 rle 값이 '274    2634760 31 2636808 31 2638856 31 2640904 31 26...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341848883.png'와 'Hamate'에 해당하는 rle 값이 '275    2634843 33 2636891 33 2638939 33 2640987 33 26...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341848883.png'와 'Scaphoid'에 해당하는 rle 값이 '276    2864044 27 2866091 29 2868137 32 2870181 37 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341848883.png'와 'Lunate'에 해당하는 rle 값이 '277    2978825 33 2980872 36 2982920 38 2984968 40 29...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341848883.png'와 'Triquetrum'에 해당하는 rle 값이 '278    2831484 29 2833532 29 2835580 29 2837628 29 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341848883.png'와 'Pisiform'에 해당하는 rle 값이 '279    2872436 32 2874483 33 2876530 34 2878578 34 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341889065.png'와 'Trapezium'에 해당하는 rle 값이 '280    2708606 22 2710654 22 2712702 22 2714750 22 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341889065.png'와 'Trapezoid'에 해당하는 rle 값이 '281    2733113 46 2735161 46 2737209 46 2739257 46 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341889065.png'와 'Capitate'에 해당하는 rle 값이 '282    2741178 55 2743226 55 2745274 55 2747322 55 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341889065.png'와 'Hamate'에 해당하는 rle 값이 '283    2773893 54 2775941 55 2777989 56 2780037 57 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341889065.png'와 'Scaphoid'에 해당하는 rle 값이 '284    2913347 13 2915395 13 2917443 13 2919491 13 29...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341889065.png'와 'Lunate'에 해당하는 rle 값이 '285    3068895 30 3070943 30 3072991 30 3075039 30 30...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341889065.png'와 'Triquetrum'에 해당하는 rle 값이 '286    2954085 27 2956133 27 2958181 27 2960229 27 29...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662341889065.png'와 'Pisiform'에 해당하는 rle 값이 '287    3019638 35 3021686 36 3023734 37 3025782 38 30...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662342205281.png'와 'Trapezium'에 해당하는 rle 값이 '288    2855717 27 2857764 30 2859811 32 2861858 35 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662342205281.png'와 'Trapezoid'에 해당하는 rle 값이 '289    2880332 48 2882380 48 2884428 48 2886476 48 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662342205281.png'와 'Capitate'에 해당하는 rle 값이 '290    2806761 31 2808809 31 2810857 31 2812905 31 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662342205281.png'와 'Hamate'에 해당하는 rle 값이 '291    2823206 61 2825254 62 2827302 62 2829350 62 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662342205281.png'와 'Scaphoid'에 해당하는 rle 값이 '292    3060601 23 3062649 23 3064697 23 3066745 23 30...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662342205281.png'와 'Lunate'에 해당하는 rle 값이 '293    3134421 46 3136469 46 3138517 46 3140565 46 31...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662342205281.png'와 'Triquetrum'에 해당하는 rle 값이 '294    3028056 32 3030104 32 3032152 32 3034200 32 30...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662342205281.png'와 'Pisiform'에 해당하는 rle 값이 '295    3159122 35 3161170 36 3163218 37 3165266 37 31...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662342232684.png'와 'Trapezium'에 해당하는 rle 값이 '296    2880659 33 2882707 33 2884755 33 2886803 33 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662342232684.png'와 'Trapezoid'에 해당하는 rle 값이 '297    2880609 38 2882657 38 2884705 38 2886753 38 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662342232684.png'와 'Capitate'에 해당하는 rle 값이 '298    2839498 37 2841546 37 2843594 37 2845642 37 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662342232684.png'와 'Hamate'에 해당하는 rle 값이 '299    2872192 69 2874238 71 2876284 73 2878332 73 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662342232684.png'와 'Scaphoid'에 해당하는 rle 값이 '300    3093575 29 3095623 29 3097671 29 3099719 29 31...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662342232684.png'와 'Lunate'에 해당하는 rle 값이 '301    3191791 45 3193839 45 3195887 45 3197935 45 31...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662342232684.png'와 'Triquetrum'에 해당하는 rle 값이 '302    3076969 31 3079017 31 3081065 31 3083113 31 30...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662342232684.png'와 'Pisiform'에 해당하는 rle 값이 '303    3175276 35 3177324 35 3179372 35 3181420 35 31...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662342284287.png'와 'Trapezium'에 해당하는 rle 값이 '304    2659143 29 2661191 29 2663239 29 2665287 29 26...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1662342284287.png'와 'Trapezoid'에 해당하는 rle 값이 '305    2667384 31 2669429 34 2671476 35 2673523 36 26...
# Name: rle, dtype: object'로 변경되었습니다.
# ...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154289655.png'와 'Hamate'에 해당하는 rle 값이 '2195    2454502 21 2456550 22 2458598 22 2460646 22 24...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154289655.png'와 'Scaphoid'에 해당하는 rle 값이 '2196    2421553 6 2423601 6 2425649 6 2427697 6 242974...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154289655.png'와 'Lunate'에 해당하는 rle 값이 '2197    2593643 45 2595691 45 2597739 45 2599787 45 26...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154289655.png'와 'Triquetrum'에 해당하는 rle 값이 '2198    2618345 47 2620393 47 2622441 47 2624489 47 26...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154289655.png'와 'Pisiform'에 해당하는 rle 값이 '2199    2675708 23 2677755 24 2679802 26 2681849 28 26...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154311264.png'와 'Trapezium'에 해당하는 rle 값이 '2200    2274404 17 2276452 17 2278500 17 2280548 17 22...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154311264.png'와 'Trapezoid'에 해당하는 rle 값이 '2201    2323530 32 2325578 32 2327626 32 2329674 32 23...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154311264.png'와 'Capitate'에 해당하는 rle 값이 '2202    2405386 27 2407434 27 2409482 27 2411530 27 24...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154311264.png'와 'Hamate'에 해당하는 rle 값이 '2203    2495440 22 2497488 23 2499536 23 2501584 23 25...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154311264.png'와 'Scaphoid'에 해당하는 rle 값이 '2204    2495650 1 2497695 6 2499742 9 2501730 2 250178...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154311264.png'와 'Lunate'에 해당하는 rle 값이 '2205    2634813 38 2636861 38 2638909 38 2640957 38 26...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154311264.png'와 'Triquetrum'에 해당하는 rle 값이 '2206    2659262 49 2661310 49 2663358 49 2665406 49 26...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154311264.png'와 'Pisiform'에 해당하는 rle 값이 '2207    2716616 23 2718664 23 2720712 23 2722760 23 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154379949.png'와 'Trapezium'에 해당하는 rle 값이 '2208    2241340 26 2243388 26 2245436 26 2247484 26 22...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154379949.png'와 'Trapezoid'에 해당하는 rle 값이 '2209    2282334 29 2284382 29 2286430 29 2288478 29 22...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154379949.png'와 'Capitate'에 해당하는 rle 값이 '2210    2380707 20 2382755 20 2384803 20 2386851 20 23...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154379949.png'와 'Hamate'에 해당하는 rle 값이 '2211    2479078 36 2481126 36 2483174 36 2485222 36 24...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154379949.png'와 'Scaphoid'에 해당하는 rle 값이 '2212    2474853 3 2476899 6 2478946 7 2480993 9 248297...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154379949.png'와 'Lunate'에 해당하는 rle 값이 '2213    2626419 31 2628467 31 2630515 31 2632563 31 26...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154379949.png'와 'Triquetrum'에 해당하는 rle 값이 '2214    2651131 31 2653179 31 2655227 31 2657275 31 26...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154379949.png'와 'Pisiform'에 해당하는 rle 값이 '2215    2708459 35 2710506 37 2712554 38 2714601 40 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154396535.png'와 'Trapezium'에 해당하는 rle 값이 '2216    2249826 27 2251874 27 2253922 27 2255970 27 22...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154396535.png'와 'Trapezoid'에 해당하는 rle 값이 '2217    2290732 41 2292780 41 2294828 41 2296876 41 22...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154396535.png'와 'Capitate'에 해당하는 rle 값이 '2218    2388987 29 2391035 29 2393083 29 2395131 29 23...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154396535.png'와 'Hamate'에 해당하는 rle 값이 '2219    2495413 28 2497459 31 2499506 34 2501552 36 25...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154396535.png'와 'Scaphoid'에 해당하는 rle 값이 '2220    2468951 4 2470997 6 2473043 9 2475089 12 24771...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154396535.png'와 'Lunate'에 해당하는 rle 값이 '2221    2634796 39 2636844 39 2638892 39 2640940 39 26...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154396535.png'와 'Triquetrum'에 해당하는 rle 값이 '2222    2667430 49 2669477 52 2671524 55 2673571 58 26...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154396535.png'와 'Pisiform'에 해당하는 rle 값이 '2223    2692020 35 2694068 35 2696116 35 2698164 35 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154449598.png'와 'Trapezium'에 해당하는 rle 값이 '2224    2478822 37 2480870 37 2482918 37 2484966 37 24...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154449598.png'와 'Trapezoid'에 해당하는 rle 값이 '2225    2527993 42 2530039 44 2532086 45 2534133 46 25...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154449598.png'와 'Capitate'에 해당하는 rle 값이 '2226    2609998 40 2612046 40 2614094 40 2616142 40 26...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154449598.png'와 'Hamate'에 해당하는 rle 값이 '2227    2708396 42 2710444 42 2712492 42 2714540 42 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154449598.png'와 'Scaphoid'에 해당하는 rle 값이 '2228    2720458 2 2722503 6 2724550 9 2726596 13 27286...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154449598.png'와 'Lunate'에 해당하는 rle 값이 '2229    2888477 26 2890525 29 2892573 34 2894621 36 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154449598.png'와 'Triquetrum'에 해당하는 rle 값이 '2230    2905012 35 2907060 35 2909108 35 2911156 35 29...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154449598.png'와 'Pisiform'에 해당하는 rle 값이 '2231    2970553 35 2972599 37 2974646 39 2976694 41 29...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154464821.png'와 'Trapezium'에 해당하는 rle 값이 '2232    2446413 26 2448461 26 2450509 26 2452557 26 24...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154464821.png'와 'Trapezoid'에 해당하는 rle 값이 '2233    2503702 43 2505750 45 2507798 47 2509846 48 25...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154464821.png'와 'Capitate'에 해당하는 rle 값이 '2234    2585535 47 2587583 47 2589631 47 2591679 47 25...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154464821.png'와 'Hamate'에 해당하는 rle 값이 '2235    2675563 44 2677611 44 2679659 44 2681707 44 26...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154464821.png'와 'Scaphoid'에 해당하는 rle 값이 '2236    2710594 9 2712640 14 2714686 19 2716733 23 271...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154464821.png'와 'Lunate'에 해당하는 rle 값이 '2237    2872325 30 2874373 30 2876421 30 2878469 30 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154464821.png'와 'Triquetrum'에 해당하는 rle 값이 '2238    2880351 43 2882399 43 2884447 43 2886495 43 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154464821.png'와 'Pisiform'에 해당하는 rle 값이 '2239    2937723 34 2939770 36 2941818 36 2943866 36 29...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154538676.png'와 'Trapezium'에 해당하는 rle 값이 '2240    2298757 26 2300803 29 2302850 32 2304897 34 23...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154538676.png'와 'Trapezoid'에 해당하는 rle 값이 '2241    2388876 48 2390924 48 2392972 48 2395020 48 23...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154538676.png'와 'Capitate'에 해당하는 rle 값이 '2242    2503653 29 2505701 29 2507749 29 2509797 29 25...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154538676.png'와 'Hamate'에 해당하는 rle 값이 '2243    2634793 29 2636841 29 2638889 29 2640937 29 26...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154538676.png'와 'Scaphoid'에 해당하는 rle 값이 '2244    2552652 18 2554700 18 2556748 18 2558796 18 25...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154538676.png'와 'Lunate'에 해당하는 rle 값이 '2245    2814865 57 2816913 59 2818961 61 2821009 63 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154538676.png'와 'Triquetrum'에 해당하는 rle 값이 '2246    2823206 40 2825254 40 2827302 40 2829350 40 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154538676.png'와 'Pisiform'에 해당하는 rle 값이 '2247    2855966 35 2858012 37 2860059 38 2862105 40 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154558481.png'와 'Trapezium'에 해당하는 rle 값이 '2248    2331737 24 2333785 24 2335833 24 2337881 24 23...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154558481.png'와 'Trapezoid'에 해당하는 rle 값이 '2249    2430001 42 2432049 42 2434097 42 2436145 42 24...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154558481.png'와 'Capitate'에 해당하는 rle 값이 '2250    2503643 28 2505687 35 2507733 39 2509779 42 25...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154558481.png'와 'Hamate'에 해당하는 rle 값이 '2251    2601860 27 2601893 8 2603908 27 2603941 8 2605...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154558481.png'와 'Scaphoid'에 해당하는 rle 값이 '2252    2602067 17 2604115 17 2606163 17 2608211 17 26...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154558481.png'와 'Lunate'에 해당하는 rle 값이 '2253    2814976 54 2817023 55 2819070 56 2821117 57 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154558481.png'와 'Triquetrum'에 해당하는 rle 값이 '2254    2798447 48 2800495 50 2802543 51 2804591 51 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154558481.png'와 'Pisiform'에 해당하는 rle 값이 '2255    2855828 43 2857875 45 2859922 46 2861969 47 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154611151.png'와 'Trapezium'에 해당하는 rle 값이 '2256    2216793 29 2218841 29 2220889 29 2222937 29 22...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154611151.png'와 'Trapezoid'에 해당하는 rle 값이 '2257    2274167 35 2276214 36 2278260 38 2280307 39 22...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154611151.png'와 'Capitate'에 해당하는 rle 값이 '2258    2356155 36 2358203 36 2360251 36 2362299 36 23...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154611151.png'와 'Hamate'에 해당하는 rle 값이 '2259    2446332 19 2448380 19 2450428 19 2452476 19 24...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154611151.png'와 'Scaphoid'에 해당하는 rle 값이 '2260    2450223 9 2450298 2 2452268 13 2452345 3 24543...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154611151.png'와 'Lunate'에 해당하는 rle 값이 '2261    2569087 36 2571134 38 2573182 39 2575230 41 25...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154611151.png'와 'Triquetrum'에 해당하는 rle 값이 '2262    2602003 23 2604047 29 2606092 33 2608139 34 26...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154611151.png'와 'Pisiform'에 해당하는 rle 값이 '2263    2634752 31 2636798 34 2638846 35 2640894 35 26...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154624841.png'와 'Trapezium'에 해당하는 rle 값이 '2264    2339937 25 2341985 25 2344033 25 2346081 25 23...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154624841.png'와 'Trapezoid'에 해당하는 rle 값이 '2265    2380856 37 2382904 37 2384952 37 2387000 37 23...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154624841.png'와 'Capitate'에 해당하는 rle 값이 '2266    2446301 49 2448349 49 2450397 49 2452445 49 24...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154624841.png'와 'Hamate'에 해당하는 rle 값이 '2267    2519986 24 2522032 27 2524080 28 2526127 30 25...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154624841.png'와 'Scaphoid'에 해당하는 rle 값이 '2268    2567243 1 2569290 3 2571338 5 2573386 6 257543...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154624841.png'와 'Lunate'에 해당하는 rle 값이 '2269    2675733 35 2677780 36 2679826 39 2681873 40 26...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154624841.png'와 'Triquetrum'에 해당하는 rle 값이 '2270    2642830 23 2644878 23 2646926 23 2648974 23 26...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1664154624841.png'와 'Pisiform'에 해당하는 rle 값이 '2271    2691987 37 2694035 37 2696083 37 2698131 37 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1667354218823.png'와 'Trapezium'에 해당하는 rle 값이 '2272    2790247 24 2792295 24 2794343 24 2796391 24 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1667354218823.png'와 'Trapezoid'에 해당하는 rle 값이 '2273    2814873 36 2816920 37 2818967 38 2821015 38 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1667354218823.png'와 'Capitate'에 해당하는 rle 값이 '2274    2790407 62 2792449 68 2794491 74 2796538 75 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1667354218823.png'와 'Hamate'에 해당하는 rle 값이 '2275    2815060 55 2817108 55 2819156 55 2821204 55 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1667354218823.png'와 'Scaphoid'에 해당하는 rle 값이 '2276    2986932 28 2988980 28 2991028 28 2993076 28 29...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1667354218823.png'와 'Lunate'에 해당하는 rle 값이 '2277    3085332 39 3087380 39 3089428 39 3091476 39 30...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1667354218823.png'와 'Triquetrum'에 해당하는 rle 값이 '2278    2995330 29 2997378 29 2999426 29 3001474 29 30...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1667354218823.png'와 'Pisiform'에 해당하는 rle 값이 '2279    3085432 31 3087480 31 3089528 31 3091576 31 30...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1667354234602.png'와 'Trapezium'에 해당하는 rle 값이 '2280    2765981 30 2768029 30 2770077 30 2772125 30 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1667354234602.png'와 'Trapezoid'에 해당하는 rle 값이 '2281    2782307 33 2784352 36 2786398 38 2788445 39 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1667354234602.png'와 'Capitate'에 해당하는 rle 값이 '2282    2757591 63 2759639 63 2761687 63 2763735 63 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1667354234602.png'와 'Hamate'에 해당하는 rle 값이 '2283    2782105 49 2784151 51 2786198 52 2788244 54 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1667354234602.png'와 'Scaphoid'에 해당하는 rle 값이 '2284    2954327 19 2956374 20 2958421 21 2960468 22 29...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1667354234602.png'와 'Lunate'에 해당하는 rle 값이 '2285    3060714 27 3062762 27 3064810 27 3066858 27 30...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1667354234602.png'와 'Triquetrum'에 해당하는 rle 값이 '2286    2970498 30 2972546 30 2974594 30 2976642 30 29...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1667354234602.png'와 'Pisiform'에 해당하는 rle 값이 '2287    3036035 40 3038082 42 3040129 43 3042176 44 30...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1667354405140.png'와 'Trapezium'에 해당하는 rle 값이 '2288    2700077 31 2702125 31 2704173 31 2706221 31 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1667354405140.png'와 'Trapezoid'에 해당하는 rle 값이 '2289    2716495 50 2718542 51 2720590 51 2722637 52 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1667354405140.png'와 'Capitate'에 해당하는 rle 값이 '2290    2683859 47 2685876 79 2687913 91 2689959 94 26...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1667354405140.png'와 'Hamate'에 해당하는 rle 값이 '2291    2708488 66 2710536 66 2712584 66 2714632 66 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1667354405140.png'와 'Scaphoid'에 해당하는 rle 값이 '2292    2872193 7 2874241 7 2876289 7 2878337 7 288038...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1667354405140.png'와 'Lunate'에 해당하는 rle 값이 '2293    3003331 53 3005379 53 3007427 53 3009475 53 30...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1667354405140.png'와 'Triquetrum'에 해당하는 rle 값이 '2294    2905143 39 2907191 39 2909239 39 2911287 39 29...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1667354405140.png'와 'Pisiform'에 해당하는 rle 값이 '2295    2962478 35 2964526 35 2966574 35 2968622 35 29...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1667354424553.png'와 'Trapezium'에 해당하는 rle 값이 '2296    2618515 33 2620563 33 2622611 33 2624659 33 26...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1667354424553.png'와 'Trapezoid'에 해당하는 rle 값이 '2297    2626646 55 2628694 56 2630742 57 2632790 58 26...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1667354424553.png'와 'Capitate'에 해당하는 rle 값이 '2298    2577377 84 2579424 90 2581472 93 2583519 96 25...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1667354424553.png'와 'Hamate'에 해당하는 rle 값이 '2299    2593696 61 2595744 61 2597792 61 2599840 62 26...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1667354424553.png'와 'Scaphoid'에 해당하는 rle 값이 '2300    2790479 12 2792527 12 2794575 12 2796623 12 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1667354424553.png'와 'Lunate'에 해당하는 rle 값이 '2301    2880507 33 2882555 33 2884603 33 2886651 33 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1667354424553.png'와 'Triquetrum'에 해당하는 rle 값이 '2302    2790284 27 2792332 27 2794380 27 2796428 27 27...
# Name: rle, dtype: object'로 변경되었습니다.
# 'image1667354424553.png'와 'Pisiform'에 해당하는 rle 값이 '2303    2839453 32 2841501 32 2843549 32 2845597 32 28...
# Name: rle, dtype: object'로 변경되었습니다.
# 수정된 파일은 /data/ephemeral/home/Jungyeon/Yolo/ensemble.csv에 저장되었습니다.
