# %%
from inference import Inference
from glob import glob

# %%
dir_path = 'trained_models/cont'
model_dir_paths = glob(dir_path + '/*')
model_dir_paths = sorted(model_dir_paths)
inferences = []

model_dir_path = model_dir_paths[1]
inference = Inference(model_dir_path)
inference.inference_and_save(mode='train')
inference.inference_and_save(mode='valid')
inference.inference_and_save(mode='test')
# Out:
#   0%|          | 0/640 [00:01<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 8
#       6 model_dir_path = model_dir_paths[1]
#       7 inference = Inference(model_dir_path)
# ----> 8 inference.inference_and_save(mode='train')
#       9 inference.inference_and_save(mode='valid')
#
# File ~/Dongjin/level2-cv-semanticsegmentation-cv-02-lv3/Baseline/Dongjin/transformers_1120/inference.py:114, in Inference.inference_and_save(self, mode, save_path, thr)
#     113 def inference_and_save(self, mode, save_path=None, thr=0.5):
# --> 114     rles, filename_and_class = self.inference(mode, thr)
#     115     classes, filename = zip(*[x.split("_") for x in filename_and_class])
#     116     image_name = [os.path.basename(f) for f in filename]
#
# File ~/Dongjin/level2-cv-semanticsegmentation-cv-02-lv3/Baseline/Dongjin/transformers_1120/inference.py:99, in Inference.inference(self, mode, thr)
#      97 for batch, image_names in tqdm(data_loader, total=len(data_loader)):
#      98     inputs = batch["pixel_values"].to('cuda')
# ---> 99     outputs = self.model(inputs).logits
#     101     outputs = F.interpolate(outputs, size=(2048, 2048), mode="bilinear")
#     102     outputs = torch.sigmoid(outputs)
#
# File /data/ephemeral/conda_envs/torch/lib/python3.10/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File /data/ephemeral/conda_envs/torch/lib/python3.10/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File /data/ephemeral/conda_envs/torch/lib/python3.10/site-packages/transformers/models/upernet/modeling_upernet.py:404, in UperNetForSemanticSegmentation.forward(self, pixel_values, output_attentions, output_hidden_states, labels, return_dict)
#     399 output_hidden_states = (
#     400     output_hidden_states if output_hidden_states is not None else self.config.output_hidden_states
#     401 )
#     402 output_attentions = output_attentions if output_attentions is not None else self.config.output_attentions
# --> 404 outputs = self.backbone.forward_with_filtered_kwargs(
#     405     pixel_values, output_hidden_states=output_hidden_states, output_attentions=output_attentions
#     406 )
#     407 features = outputs.feature_maps
#     409 logits = self.decode_head(features)
#
# File /data/ephemeral/conda_envs/torch/lib/python3.10/site-packages/transformers/utils/backbone_utils.py:235, in BackboneMixin.forward_with_filtered_kwargs(self, *args, **kwargs)
#     233 signature = dict(inspect.signature(self.forward).parameters)
#     234 filtered_kwargs = {k: v for k, v in kwargs.items() if k in signature}
# --> 235 return self(*args, **filtered_kwargs)
#
# File /data/ephemeral/conda_envs/torch/lib/python3.10/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File /data/ephemeral/conda_envs/torch/lib/python3.10/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File /data/ephemeral/conda_envs/torch/lib/python3.10/site-packages/transformers/models/convnext/modeling_convnext.py:522, in ConvNextBackbone.forward(self, pixel_values, output_hidden_states, return_dict)
#     517 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
#     518 output_hidden_states = (
#     519     output_hidden_states if output_hidden_states is not None else self.config.output_hidden_states
#     520 )
# --> 522 embedding_output = self.embeddings(pixel_values)
#     524 outputs = self.encoder(
#     525     embedding_output,
#     526     output_hidden_states=True,
#     527     return_dict=return_dict,
#     528 )
#     530 hidden_states = outputs.hidden_states if return_dict else outputs[1]
#
# File /data/ephemeral/conda_envs/torch/lib/python3.10/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File /data/ephemeral/conda_envs/torch/lib/python3.10/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File /data/ephemeral/conda_envs/torch/lib/python3.10/site-packages/transformers/models/convnext/modeling_convnext.py:139, in ConvNextEmbeddings.forward(self, pixel_values)
#     137 num_channels = pixel_values.shape[1]
#     138 if num_channels != self.num_channels:
# --> 139     raise ValueError(
#     140         "Make sure that the channel dimension of the pixel values match with the one set in the configuration."
#     141     )
#     142 embeddings = self.patch_embeddings(pixel_values)
#     143 embeddings = self.layernorm(embeddings)
#
# ValueError: Make sure that the channel dimension of the pixel values match with the one set in the configuration.
