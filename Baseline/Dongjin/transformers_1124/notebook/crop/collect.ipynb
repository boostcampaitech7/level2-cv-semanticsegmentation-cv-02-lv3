# %%
import pandas as pd
from glob import glob
import os
from collections import defaultdict
import numpy as np

import sys
sys.path.append('../../')
import utils

# %%
modes = ['train', 'valid', 'test']
file_name_format = '{mode}_upernet-convnext-small_cont_size_1024_cont_weight_ep_47_vdice_0.9716.csv'
data_dir_path = '/data/ephemeral/home/data'
image_paths = glob(data_dir_path + '/**/*.png', recursive=True)

result = {}

for mode in modes:
    file_name = file_name_format.format(mode=mode)
    file_path = f'result/{file_name}'
    df = pd.read_csv(file_path)

    for i, row in df.iterrows():
        image_name = row.image_name
        target_image_paths = [image_path for image_path in image_paths if image_name in image_path]
        if len(target_image_paths) == 0 or 1 < len(target_image_paths):
            raise(Exception("조건을 만족하는 이미지가 0장이거나 1장 초과입니다."))

        image_name = os.path.basename(target_image_paths[0])
        if image_name in result:
            raise(Exception("동일한 이미지 이름이 여러 장입니다."))
        
        result[image_name] = {}

        for k, v in row.items():
            if k == 'image_name':
                continue
            # v 파싱
            v = v.replace(' ', '')
            v = v.replace('(', '')
            v = v.replace(')', '')
            v = [int(i) for i in v.split(',')]
            
            result[image_name][k] = v

utils.save_json(result, 'result/crop_info.json')

# %%
crop
# Out:
# {'image1661144206667.png': {'crop_finger': [477, 1599, 255, 1516],
#   'crop_backhand': [774, 1258, 1335, 1686],
#   'crop_fingerbackhand': [477, 1599, 255, 1686],
#   'crop_arm': [800, 1257, 1507, 2047]},
#  'image1661144246917.png': {'crop_finger': [485, 1508, 274, 1510],
#   'crop_backhand': [786, 1259, 1343, 1693],
#   'crop_fingerbackhand': [485, 1508, 274, 1693],
#   'crop_arm': [779, 1233, 1516, 2047]},
#  'image1661144310162.png': {'crop_finger': [507, 1572, 239, 1387],
#   'crop_backhand': [773, 1213, 1233, 1541],
#   'crop_fingerbackhand': [507, 1572, 239, 1541],
#   'crop_arm': [808, 1221, 1382, 2047]},
#  'image1661144351691.png': {'crop_finger': [526, 1546, 306, 1467],
#   'crop_backhand': [853, 1277, 1296, 1607],
#   'crop_fingerbackhand': [526, 1546, 306, 1607],
#   'crop_arm': [870, 1257, 1436, 2047]},
#  'image1661144825412.png': {'crop_finger': [474, 1606, 311, 1522],
#   'crop_backhand': [802, 1250, 1333, 1680],
#   'crop_fingerbackhand': [474, 1606, 311, 1680],
#   'crop_arm': [824, 1275, 1477, 2047]},
#  'image1661144852117.png': {'crop_finger': [470, 1570, 269, 1478],
#   'crop_backhand': [790, 1233, 1296, 1643],
#   'crop_fingerbackhand': [470, 1570, 269, 1643],
#   'crop_arm': [767, 1215, 1440, 2047]},
#  'image1661145075929.png': {'crop_finger': [449, 1561, 287, 1507],
#   'crop_backhand': [763, 1191, 1341, 1665],
#   'crop_fingerbackhand': [449, 1561, 287, 1665],
#   'crop_arm': [786, 1212, 1492, 2047]},
#  'image1661145103549.png': {'crop_finger': [458, 1634, 252, 1506],
#   'crop_backhand': [767, 1200, 1314, 1646],
#   'crop_fingerbackhand': [458, 1634, 252, 1646],
#   'crop_arm': [755, 1169, 1461, 2047]},
#  'image1661145193855.png': {'crop_finger': [539, 1597, 265, 1518],
#   'crop_backhand': [785, 1221, 1356, 1667],
#   'crop_fingerbackhand': [539, 1597, 265, 1667],
#   'crop_arm': [802, 1226, 1497, 2047]},
#  'image1661145229731.png': {'crop_finger': [456, 1519, 265, 1520],
#   'crop_backhand': [766, 1224, 1369, 1684],
#   'crop_fingerbackhand': [456, 1519, 265, 1684],
#   'crop_arm': [765, 1175, 1507, 2047]},
#  'image1661145286692.png': {'crop_finger': [404, 1510, 231, 1466],
#   'crop_backhand': [809, 1234, 1251, 1585],
#   'crop_fingerbackhand': [404, 1510, 231, 1585],
#   'crop_arm': [838, 1253, 1410, 2047]},
#  'image1661145313061.png': {'crop_finger': [460, 1603, 314, 1548],
#   'crop_backhand': [784, 1206, 1332, 1674],
#   'crop_fingerbackhand': [460, 1603, 314, 1674],
#   'crop_arm': [792, 1183, 1489, 2047]},
#  'image1661145407161.png': {'crop_finger': [460, 1542, 334, 1463],
#   'crop_backhand': [774, 1209, 1292, 1621],
#   'crop_fingerbackhand': [460, 1542, 334, 1621],
#   'crop_arm': [822, 1223, 1461, 2047]},
#  'image1661145432967.png': {'crop_finger': [488, 1597, 390, 1517],
#   'crop_backhand': [795, 1227, 1350, 1674],
#   'crop_fingerbackhand': [488, 1597, 390, 1674],
#   'crop_arm': [788, 1182, 1506, 2047]},
#  'image1661146664360.png': {'crop_finger': [489, 1615, 283, 1533],
#   'crop_backhand': [744, 1190, 1376, 1726],
#   'crop_fingerbackhand': [489, 1615, 283, 1726],
#   'crop_arm': [777, 1212, 1574, 2047]},
#  'image1661146685158.png': {'crop_finger': [509, 1534, 228, 1485],
#   'crop_backhand': [855, 1298, 1322, 1683],
#   'crop_fingerbackhand': [509, 1534, 228, 1683],
#   'crop_arm': [844, 1269, 1514, 2047]},
#  'image1661147072358.png': {'crop_finger': [413, 1491, 340, 1547],
#   'crop_backhand': [740, 1193, 1369, 1690],
#   'crop_fingerbackhand': [413, 1491, 340, 1690],
#   'crop_arm': [772, 1198, 1532, 2047]},
#  'image1661147098202.png': {'crop_finger': [528, 1596, 316, 1500],
#   'crop_backhand': [785, 1233, 1333, 1659],
#   'crop_fingerbackhand': [528, 1596, 316, 1659],
#   'crop_arm': [773, 1206, 1489, 2047]},
#  'image1661216747360.png': {'crop_finger': [413, 1554, 297, 1560],
#   'crop_backhand': [703, 1200, 1365, 1748],
#   'crop_fingerbackhand': [413, 1554, 297, 1748],
#   'crop_arm': [726, 1215, 1570, 2047]},
#  'image1661216788592.png': {'crop_finger': [445, 1633, 289, 1550],
#   'crop_backhand': [819, 1329, 1364, 1761],
#   'crop_fingerbackhand': [445, 1633, 289, 1761],
#   'crop_arm': [818, 1297, 1576, 2047]},
#  'image1661216876670.png': {'crop_finger': [530, 1535, 334, 1492],
#   'crop_backhand': [771, 1190, 1319, 1650],
#   'crop_fingerbackhand': [530, 1535, 334, 1650],
#   'crop_arm': [800, 1210, 1480, 2047]},
#  'image1661216907060.png': {'crop_finger': [489, 1502, 355, 1517],
#   'crop_backhand': [817, 1245, 1335, 1679],
#   'crop_fingerbackhand': [489, 1502, 355, 1679],
#   'crop_arm': [782, 1200, 1529, 2047]},
#  'image1661217116456.png': {'crop_finger': [548, 1518, 328, 1520],
#   'crop_backhand': [791, 1246, 1342, 1676],
#   'crop_fingerbackhand': [548, 1518, 328, 1676],
#   'crop_arm': [849, 1287, 1512, 2047]},
#  'image1661217144265.png': {'crop_finger': [501, 1557, 288, 1488],
#   'crop_backhand': [783, 1238, 1285, 1632],
#   'crop_fingerbackhand': [501, 1557, 288, 1632],
#   'crop_arm': [752, 1191, 1459, 2047]},
#  'image1661217260585.png': {'crop_finger': [467, 1528, 185, 1441],
#   'crop_backhand': [748, 1184, 1263, 1605],
#   'crop_fingerbackhand': [467, 1528, 185, 1605],
#   'crop_arm': [769, 1198, 1439, 2047]},
#  'image1661217290462.png': {'crop_finger': [487, 1590, 248, 1500],
#   'crop_backhand': [808, 1248, 1322, 1652],
#   'crop_fingerbackhand': [487, 1590, 248, 1652],
#   'crop_arm': [797, 1216, 1479, 2047]},
#  'image1661218865003.png': {'crop_finger': [352, 1521, 385, 1512],
#   'crop_backhand': [781, 1204, 1324, 1650],
#   'crop_fingerbackhand': [352, 1521, 385, 1650],
#   'crop_arm': [795, 1204, 1476, 2047]},
#  'image1661218881444.png': {'crop_finger': [517, 1619, 370, 1503],
#   'crop_backhand': [795, 1226, 1309, 1641],
#   'crop_fingerbackhand': [517, 1619, 370, 1641],
#   'crop_arm': [782, 1205, 1472, 2047]},
#  'image1661219523078.png': {'crop_finger': [363, 1618, 273, 1574],
#   'crop_backhand': [781, 1215, 1399, 1731],
#   'crop_fingerbackhand': [363, 1618, 273, 1731],
#   'crop_arm': [775, 1240, 1529, 2047]},
#  'image1661219796151.png': {'crop_finger': [414, 1651, 230, 1499],
#   'crop_backhand': [861, 1296, 1317, 1669],
#   'crop_fingerbackhand': [414, 1651, 230, 1669],
#   'crop_arm': [831, 1278, 1487, 2047]},
#  'image1661221248296.png': {'crop_finger': [486, 1533, 284, 1489],
#   'crop_backhand': [766, 1216, 1325, 1679],
#   'crop_fingerbackhand': [486, 1533, 284, 1679],
#   'crop_arm': [789, 1228, 1486, 2047]},
#  'image1661221262696.png': {'crop_finger': [477, 1585, 273, 1497],
#   'crop_backhand': [799, 1243, 1324, 1681],
#   'crop_fingerbackhand': [477, 1585, 273, 1681],
#   'crop_arm': [775, 1218, 1494, 2047]},
#  'image1661303800530.png': {'crop_finger': [438, 1478, 306, 1426],
#   'crop_backhand': [716, 1168, 1255, 1581],
#   'crop_fingerbackhand': [438, 1478, 306, 1581],
#   'crop_arm': [775, 1248, 1423, 2047]},
#  'image1661303818126.png': {'crop_finger': [549, 1589, 264, 1383],
#   'crop_backhand': [820, 1273, 1196, 1531],
#   'crop_fingerbackhand': [549, 1589, 264, 1531],
#   'crop_arm': [795, 1210, 1347, 2047]},
#  'image1661303869369.png': {'crop_finger': [493, 1533, 371, 1473],
#   'crop_backhand': [795, 1207, 1289, 1619],
#   'crop_fingerbackhand': [493, 1533, 371, 1619],
#   'crop_arm': [804, 1219, 1442, 2047]},
#  'image1661303896767.png': {'crop_finger': [530, 1554, 378, 1468],
#   'crop_backhand': [759, 1186, 1286, 1616],
#   'crop_fingerbackhand': [530, 1554, 378, 1616],
#   'crop_arm': [732, 1154, 1444, 2047]},
#  'image1661304293036.png': {'crop_finger': [406, 1511, 364, 1560],
#   'crop_backhand': [759, 1196, 1380, 1725],
#   'crop_fingerbackhand': [406, 1511, 364, 1725],
#   'crop_arm': [792, 1218, 1556, 2047]},
#  'image1661304319731.png': {'crop_finger': [571, 1583, 325, 1523],
#   'crop_backhand': [768, 1210, 1341, 1693],
#   'crop_fingerbackhand': [571, 1583, 325, 1693],
#   'crop_arm': [739, 1166, 1512, 2047]},
#  'image1661304399229.png': {'crop_finger': [458, 1480, 337, 1543],
#   'crop_backhand': [762, 1197, 1352, 1675],
#   'crop_fingerbackhand': [458, 1480, 337, 1675],
#   'crop_arm': [796, 1209, 1509, 2047]},
#  'image1661304415730.png': {'crop_finger': [484, 1615, 321, 1515],
#   'crop_backhand': [832, 1267, 1330, 1653],
#   'crop_fingerbackhand': [484, 1615, 321, 1653],
#   'crop_arm': [829, 1228, 1483, 2047]},
#  'image1661305088598.png': {'crop_finger': [328, 1555, 245, 1519],
#   'crop_backhand': [780, 1250, 1300, 1679],
#   'crop_fingerbackhand': [328, 1555, 245, 1679],
#   'crop_arm': [801, 1266, 1495, 2047]},
#  'image1661305115919.png': {'crop_finger': [471, 1685, 192, 1473],
#   'crop_backhand': [784, 1261, 1252, 1635],
#   'crop_fingerbackhand': [471, 1685, 192, 1635],
#   'crop_arm': [757, 1228, 1452, 2047]},
#  'image1661306029301.png': {'crop_finger': [421, 1526, 305, 1517],
#   'crop_backhand': [776, 1232, 1333, 1690],
#   'crop_fingerbackhand': [421, 1526, 305, 1690],
#   'crop_arm': [792, 1215, 1494, 2047]},
#  'image1661306046305.png': {'crop_finger': [466, 1572, 226, 1446],
#   'crop_backhand': [786, 1236, 1261, 1618],
#   'crop_fingerbackhand': [466, 1572, 226, 1618],
#   'crop_arm': [787, 1217, 1416, 2047]},
#  'image1661306136685.png': {'crop_finger': [364, 1659, 161, 1461],
#   'crop_backhand': [737, 1209, 1291, 1630],
#   'crop_fingerbackhand': [364, 1659, 161, 1630],
#   'crop_arm': [758, 1203, 1449, 2047]},
#  'image1661306162532.png': {'crop_finger': [377, 1623, 188, 1484],
#   'crop_backhand': [734, 1208, 1308, 1657],
#   'crop_fingerbackhand': [377, 1623, 188, 1657],
#   'crop_arm': [725, 1175, 1470, 2047]},
#  'image1661317062396.png': {'crop_finger': [499, 1584, 375, 1499],
#   'crop_backhand': [789, 1220, 1311, 1619],
#   'crop_fingerbackhand': [499, 1584, 375, 1619],
#   'crop_arm': [825, 1226, 1458, 2047]},
#  'image1661317091360.png': {'crop_finger': [487, 1561, 401, 1545],
#   'crop_backhand': [810, 1243, 1330, 1656],
#   'crop_fingerbackhand': [487, 1561, 401, 1656],
#   'crop_arm': [807, 1197, 1492, 2047]},
#  'image1661317391266.png': {'crop_finger': [396, 1487, 188, 1488],
#   'crop_backhand': [757, 1207, 1281, 1649],
#   'crop_fingerbackhand': [396, 1487, 188, 1649],
#   'crop_arm': [782, 1222, 1481, 2047]},
#  'image1661317417826.png': {'crop_finger': [500, 1618, 198, 1500],
#   'crop_backhand': [823, 1291, 1321, 1679],
#   'crop_fingerbackhand': [500, 1618, 198, 1679],
#   'crop_arm': [803, 1247, 1501, 2047]},
#  'image1661317667402.png': {'crop_finger': [471, 1514, 293, 1474],
#   'crop_backhand': [821, 1233, 1271, 1587],
#   'crop_fingerbackhand': [471, 1514, 293, 1587],
#   'crop_arm': [844, 1244, 1419, 2047]},
#  'image1661317693696.png': {'crop_finger': [487, 1584, 230, 1421],
#   'crop_backhand': [777, 1202, 1236, 1542],
#   'crop_fingerbackhand': [487, 1584, 230, 1542],
#   'crop_arm': [756, 1164, 1374, 2047]},
#  'image1661317748865.png': {'crop_finger': [421, 1518, 318, 1442],
#   'crop_backhand': [792, 1204, 1257, 1583],
#   'crop_fingerbackhand': [421, 1518, 318, 1583],
#   'crop_arm': [816, 1215, 1417, 2047]},
#  'image1661317775801.png': {'crop_finger': [527, 1613, 337, 1463],
#   'crop_backhand': [834, 1247, 1278, 1608],
#   'crop_fingerbackhand': [527, 1613, 337, 1608],
#   'crop_arm': [821, 1217, 1440, 2047]},
#  'image1661318561230.png': {'crop_finger': [281, 1521, 126, 1479],
#   'crop_backhand': [683, 1159, 1263, 1632],
#   'crop_fingerbackhand': [281, 1521, 126, 1632],
#   'crop_arm': [693, 1176, 1447, 2047]},
#  'image1661318590468.png': {'crop_finger': [455, 1779, 196, 1557],
#   'crop_backhand': [846, 1323, 1321, 1703],
#   'crop_fingerbackhand': [455, 1779, 196, 1703],
#   'crop_arm': [813, 1299, 1527, 2047]},
#  'image1661318779413.png': {'crop_finger': [327, 1564, 302, 1548],
#   'crop_backhand': [718, 1187, 1346, 1689],
#   'crop_fingerbackhand': [327, 1564, 302, 1689],
#   'crop_arm': [746, 1201, 1517, 2047]},
#  'image1661318805314.png': {'crop_finger': [408, 1668, 280, 1527],
#   'crop_backhand': [758, 1241, 1310, 1662],
#   'crop_fingerbackhand': [408, 1668, 280, 1662],
#   'crop_arm': [738, 1198, 1478, 2047]},
#  'image1661318857820.png': {'crop_finger': [413, 1528, 232, 1468],
#   'crop_backhand': [748, 1174, 1284, 1625],
#   'crop_fingerbackhand': [413, 1528, 232, 1625],
#   'crop_arm': [740, 1156, 1425, 2047]},
#  'image1661318884439.png': {'crop_finger': [505, 1524, 257, 1476],
#   'crop_backhand': [767, 1205, 1300, 1643],
#   'crop_fingerbackhand': [505, 1524, 257, 1643],
#   'crop_arm': [761, 1176, 1444, 2047]},
#  'image1661318938038.png': {'crop_finger': [420, 1559, 166, 1525],
#   'crop_backhand': [709, 1176, 1348, 1710],
#   'crop_fingerbackhand': [420, 1559, 166, 1710],
#   'crop_arm': [739, 1224, 1527, 2047]},
#  'image1661318964936.png': {'crop_finger': [502, 1644, 165, 1529],
#   'crop_backhand': [769, 1244, 1337, 1710],
#   'crop_fingerbackhand': [502, 1644, 165, 1710],
#   'crop_arm': [728, 1205, 1514, 2047]},
#  'image1661389664418.png': {'crop_finger': [430, 1514, 290, 1406],
#   'crop_backhand': [743, 1190, 1226, 1566],
#   'crop_fingerbackhand': [430, 1514, 290, 1566],
#   'crop_arm': [766, 1190, 1394, 2047]},
#  'image1661389690781.png': {'crop_finger': [535, 1605, 311, 1433],
#   'crop_backhand': [787, 1232, 1248, 1594],
#   'crop_fingerbackhand': [535, 1605, 311, 1594],
#   'crop_arm': [784, 1201, 1415, 2047]},
#  'image1661390117495.png': {'crop_finger': [422, 1598, 281, 1515],
#   'crop_backhand': [805, 1247, 1331, 1639],
#   'crop_fingerbackhand': [422, 1598, 281, 1639],
#   'crop_arm': [835, 1259, 1475, 2047]},
#  'image1661390147363.png': {'crop_finger': [416, 1645, 197, 1447],
#   'crop_backhand': [771, 1209, 1250, 1556],
#   'crop_fingerbackhand': [416, 1645, 197, 1556],
#   'crop_arm': [775, 1181, 1385, 2047]},
#  'image1661390969994.png': {'crop_finger': [461, 1447, 266, 1440],
#   'crop_backhand': [733, 1218, 1288, 1636],
#   'crop_fingerbackhand': [461, 1447, 266, 1636],
#   'crop_arm': [769, 1229, 1454, 2047]},
#  'image1661390999869.png': {'crop_finger': [573, 1509, 274, 1449],
#   'crop_backhand': [790, 1265, 1294, 1638],
#   'crop_fingerbackhand': [573, 1509, 274, 1638],
#   'crop_arm': [782, 1221, 1447, 2047]},
#  'image1661391074265.png': {'crop_finger': [512, 1502, 243, 1442],
#   'crop_backhand': [774, 1209, 1273, 1590],
#   'crop_fingerbackhand': [512, 1502, 243, 1590],
#   'crop_arm': [801, 1192, 1414, 2047]},
#  'image1661391105683.png': {'crop_finger': [523, 1504, 250, 1438],
#   'crop_backhand': [836, 1276, 1250, 1598],
#   'crop_fingerbackhand': [523, 1504, 250, 1598],
#   'crop_arm': [838, 1246, 1420, 2047]},
#  'image1661391560138.png': {'crop_finger': [554, 1470, 205, 1385],
#   'crop_backhand': [775, 1212, 1223, 1537],
#   'crop_fingerbackhand': [554, 1470, 205, 1537],
#   'crop_arm': [806, 1212, 1368, 2047]},
#  'image1661391587575.png': {'crop_finger': [520, 1511, 275, 1453],
#   'crop_backhand': [791, 1213, 1284, 1606],
#   'crop_fingerbackhand': [520, 1511, 275, 1606],
#   'crop_arm': [801, 1197, 1425, 2047]},
#  'image1661391665806.png': {'crop_finger': [344, 1556, 159, 1455],
#   'crop_backhand': [790, 1285, 1251, 1611],
#   'crop_fingerbackhand': [344, 1556, 159, 1611],
#   'crop_arm': [825, 1292, 1428, 2047]},
#  'image1661391716556.png': {'crop_finger': [446, 1721, 214, 1520],
#   'crop_backhand': [816, 1313, 1319, 1685],
#   'crop_fingerbackhand': [446, 1721, 214, 1685],
#   'crop_arm': [820, 1281, 1484, 2047]},
#  'image1661392064531.png': {'crop_finger': [351, 1567, 167, 1513],
#   'crop_backhand': [750, 1261, 1322, 1704],
#   'crop_fingerbackhand': [351, 1567, 167, 1704],
#   'crop_arm': [780, 1262, 1512, 2047]},
#  'image1661392103627.png': {'crop_finger': [449, 1675, 184, 1520],
#   'crop_backhand': [769, 1280, 1332, 1721],
#   'crop_fingerbackhand': [449, 1675, 184, 1721],
#   'crop_arm': [754, 1241, 1528, 2047]},
#  'image1661393265464.png': {'crop_finger': [345, 1526, 144, 1508],
#   'crop_backhand': [744, 1243, 1298, 1652],
#   'crop_fingerbackhand': [345, 1526, 144, 1652],
#   'crop_arm': [769, 1232, 1473, 2047]},
#  'image1661393300595.png': {'crop_finger': [476, 1579, 264, 1618],
#   'crop_backhand': [792, 1300, 1412, 1768],
#   'crop_fingerbackhand': [476, 1579, 264, 1768],
#   'crop_arm': [769, 1245, 1601, 2047]},
#  'image1661393384829.png': {'crop_finger': [362, 1616, 75, 1454],
#   'crop_backhand': [690, 1199, 1249, 1660],
#   'crop_fingerbackhand': [362, 1616, 75, 1660],
#   'crop_arm': [723, 1206, 1476, 2047]},
#  'image1661393400879.png': {'crop_finger': [393, 1631, 143, 1533],
#   'crop_backhand': [739, 1265, 1320, 1734],
#   'crop_fingerbackhand': [393, 1631, 143, 1734],
#   'crop_arm': [730, 1212, 1544, 2047]},
#  'image1661393640253.png': {'crop_finger': [424, 1464, 190, 1416],
#   'crop_backhand': [719, 1194, 1223, 1568],
#   'crop_fingerbackhand': [424, 1464, 190, 1568],
#   'crop_arm': [753, 1196, 1386, 2047]},
#  'image1661393667533.png': {'crop_finger': [481, 1599, 257, 1488],
#   'crop_backhand': [797, 1278, 1294, 1641],
#   'crop_fingerbackhand': [481, 1599, 257, 1641],
#   'crop_arm': [774, 1214, 1469, 2047]},
#  'image1661393720347.png': {'crop_finger': [379, 1492, 247, 1457],
#   'crop_backhand': [706, 1187, 1255, 1619],
#   'crop_fingerbackhand': [379, 1492, 247, 1619],
#   'crop_arm': [758, 1219, 1443, 2047]},
#  'image1661393737086.png': {'crop_finger': [452, 1697, 218, 1421],
#   'crop_backhand': [813, 1297, 1216, 1587],
#   'crop_fingerbackhand': [452, 1697, 218, 1587],
#   'crop_arm': [796, 1248, 1401, 2047]},
#  'image1661734980185.png': {'crop_finger': [471, 1550, 196, 1427],
#   'crop_backhand': [774, 1239, 1255, 1611],
#   'crop_fingerbackhand': [471, 1550, 196, 1611],
#   'crop_arm': [796, 1243, 1410, 2047]},
#  'image1661735006875.png': {'crop_finger': [472, 1622, 182, 1404],
#   'crop_backhand': [757, 1229, 1229, 1590],
#   'crop_fingerbackhand': [472, 1622, 182, 1590],
#   'crop_arm': [735, 1202, 1391, 2047]},
#  'image1661735070323.png': {'crop_finger': [412, 1518, 167, 1444],
#   'crop_backhand': [782, 1266, 1234, 1579],
#   'crop_fingerbackhand': [412, 1518, 167, 1579],
#   'crop_arm': [812, 1277, 1388, 2047]},
#  'image1661735096834.png': {'crop_finger': [486, 1602, 219, 1509],
#   'crop_backhand': [742, 1227, 1288, 1640],
#   'crop_fingerbackhand': [486, 1602, 219, 1640],
#   'crop_arm': [732, 1183, 1444, 2047]},
#  'image1661735210854.png': {'crop_finger': [366, 1627, 80, 1351],
#   'crop_backhand': [696, 1173, 1170, 1515],
#   'crop_fingerbackhand': [366, 1627, 80, 1515],
#   'crop_arm': [717, 1186, 1333, 2047]},
#  'image1661735236610.png': {'crop_finger': [534, 1662, 217, 1491],
#   'crop_backhand': [836, 1317, 1317, 1675],
#   'crop_fingerbackhand': [534, 1662, 217, 1675],
#   'crop_arm': [830, 1285, 1491, 2047]},
#  'image1661735313035.png': {'crop_finger': [533, 1494, 241, 1472],
#   'crop_backhand': [773, 1190, 1308, 1621],
#   'crop_fingerbackhand': [533, 1494, 241, 1621],
#   'crop_arm': [792, 1199, 1445, 2047]},
#  'image1661735339609.png': {'crop_finger': [557, 1587, 246, 1483],
#   'crop_backhand': [789, 1214, 1306, 1619],
#   'crop_fingerbackhand': [557, 1587, 246, 1619],
#   'crop_arm': [784, 1187, 1442, 2047]},
#  'image1661735948504.png': {'crop_finger': [479, 1520, 222, 1481],
#   'crop_backhand': [768, 1228, 1276, 1646],
#   'crop_fingerbackhand': [479, 1520, 222, 1646],
#   'crop_arm': [785, 1231, 1461, 2047]},
#  'image1661735964312.png': {'crop_finger': [502, 1536, 184, 1437],
#   'crop_backhand': [766, 1227, 1258, 1609],
#   'crop_fingerbackhand': [502, 1536, 184, 1609],
#   'crop_arm': [765, 1202, 1420, 2047]},
#  'image1661736107465.png': {'crop_finger': [431, 1509, 181, 1418],
#   'crop_backhand': [798, 1253, 1214, 1556],
#   'crop_fingerbackhand': [431, 1509, 181, 1556],
#   'crop_arm': [825, 1242, 1366, 2047]},
#  'image1661736133844.png': {'crop_finger': [524, 1645, 209, 1412],
#   'crop_backhand': [763, 1240, 1226, 1575],
#   'crop_fingerbackhand': [524, 1645, 209, 1575],
#   'crop_arm': [756, 1183, 1392, 2047]},
#  'image1661736289639.png': {'crop_finger': [425, 1579, 174, 1411],
#   'crop_backhand': [767, 1232, 1225, 1580],
#   'crop_fingerbackhand': [425, 1579, 174, 1580],
#   'crop_arm': [796, 1240, 1399, 2047]},
#  'image1661736317458.png': {'crop_finger': [459, 1628, 247, 1509],
#   'crop_backhand': [753, 1219, 1311, 1663],
#   'crop_fingerbackhand': [459, 1628, 247, 1663],
#   'crop_arm': [720, 1170, 1479, 2047]},
#  'image1661736368856.png': {'crop_finger': [471, 1478, 209, 1432],
#   'crop_backhand': [799, 1217, 1245, 1570],
#   'crop_fingerbackhand': [471, 1478, 209, 1570],
#   'crop_arm': [817, 1214, 1396, 2047]},
#  'image1661736410568.png': {'crop_finger': [550, 1688, 248, 1480],
#   'crop_backhand': [810, 1237, 1284, 1613],
#   'crop_fingerbackhand': [550, 1688, 248, 1613],
#   'crop_arm': [797, 1206, 1442, 2047]},
#  'image1661736699353.png': {'crop_finger': [469, 1566, 149, 1437],
#   'crop_backhand': [782, 1269, 1248, 1601],
#   'crop_fingerbackhand': [469, 1566, 149, 1601],
#   'crop_arm': [805, 1266, 1415, 2047]},
#  'image1661736717602.png': {'crop_finger': [514, 1687, 193, 1491],
#   'crop_backhand': [775, 1271, 1294, 1650],
#   'crop_fingerbackhand': [514, 1687, 193, 1650],
#   'crop_arm': [755, 1226, 1471, 2047]},
#  'image1661736951130.png': {'crop_finger': [401, 1579, 182, 1531],
#   'crop_backhand': [823, 1288, 1267, 1664],
#   'crop_fingerbackhand': [401, 1579, 182, 1664],
#   'crop_arm': [831, 1267, 1467, 2047]},
#  'image1661736967350.png': {'crop_finger': [447, 1694, 109, 1404],
#   'crop_backhand': [741, 1219, 1212, 1585],
#   'crop_fingerbackhand': [447, 1694, 109, 1585],
#   'crop_arm': [772, 1202, 1376, 2047]},
#  'image1661737191600.png': {'crop_finger': [370, 1518, 103, 1474],
#   'crop_backhand': [754, 1228, 1280, 1634],
#   'crop_fingerbackhand': [370, 1518, 103, 1634],
#   'crop_arm': [760, 1235, 1445, 2047]},
#  'image1661737218472.png': {'crop_finger': [490, 1670, 149, 1514],
#   'crop_backhand': [786, 1271, 1316, 1668],
#   'crop_fingerbackhand': [490, 1670, 149, 1668],
#   'crop_arm': [760, 1236, 1489, 2047]},
#  'image1661737284144.png': {'crop_finger': [531, 1482, 348, 1469],
#   'crop_backhand': [798, 1199, 1294, 1614],
#   'crop_fingerbackhand': [531, 1482, 348, 1614],
#   'crop_arm': [808, 1221, 1443, 2047]},
#  'image1661737310510.png': {'crop_finger': [506, 1470, 335, 1427],
#   'crop_backhand': [812, 1211, 1244, 1589],
#   'crop_fingerbackhand': [506, 1470, 335, 1589],
#   'crop_arm': [785, 1182, 1412, 2047]},
#  'image1661737362347.png': {'crop_finger': [388, 1542, 194, 1552],
#   'crop_backhand': [784, 1267, 1343, 1698],
#   'crop_fingerbackhand': [388, 1542, 194, 1698],
#   'crop_arm': [813, 1268, 1461, 2047]},
#  'image1661737404974.png': {'crop_finger': [451, 1670, 174, 1497],
#   'crop_backhand': [826, 1308, 1306, 1677],
#   'crop_fingerbackhand': [451, 1670, 174, 1677],
#   'crop_arm': [821, 1272, 1471, 2047]},
#  'image1661737445703.png': {'crop_finger': [485, 1454, 300, 1409],
#   'crop_backhand': [774, 1184, 1246, 1573],
#   'crop_fingerbackhand': [485, 1454, 300, 1573],
#   'crop_arm': [791, 1183, 1394, 2047]},
#  'image1661737462468.png': {'crop_finger': [532, 1527, 383, 1472],
#   'crop_backhand': [786, 1200, 1309, 1643],
#   'crop_fingerbackhand': [532, 1527, 383, 1643],
#   'crop_arm': [782, 1173, 1461, 2047]},
#  'image1661737667056.png': {'crop_finger': [539, 1536, 254, 1434],
#   'crop_backhand': [746, 1208, 1267, 1621],
#   'crop_fingerbackhand': [539, 1536, 254, 1621],
#   'crop_arm': [766, 1209, 1438, 2047]},
#  'image1661737706000.png': {'crop_finger': [519, 1506, 264, 1447],
#   'crop_backhand': [826, 1289, 1277, 1618],
#   'crop_fingerbackhand': [519, 1506, 264, 1618],
#   'crop_arm': [808, 1257, 1452, 2047]},
#  'image1661737756687.png': {'crop_finger': [512, 1547, 278, 1471],
#   'crop_backhand': [813, 1228, 1300, 1634],
#   'crop_fingerbackhand': [512, 1547, 278, 1634],
#   'crop_arm': [837, 1231, 1451, 2047]},
#  'image1661737788266.png': {'crop_finger': [528, 1467, 285, 1443],
#   'crop_backhand': [830, 1243, 1292, 1630],
#   'crop_fingerbackhand': [528, 1467, 285, 1630],
#   'crop_arm': [813, 1220, 1436, 2047]},
#  'image1661737831600.png': {'crop_finger': [387, 1501, 195, 1423],
#   'crop_backhand': [760, 1208, 1240, 1592],
#   'crop_fingerbackhand': [387, 1501, 195, 1592],
#   'crop_arm': [789, 1213, 1417, 2047]},
#  'image1661737858331.png': {'crop_finger': [497, 1574, 228, 1470],
#   'crop_backhand': [784, 1242, 1283, 1654],
#   'crop_fingerbackhand': [497, 1574, 228, 1654],
#   'crop_arm': [761, 1201, 1468, 2047]},
#  'image1661738545281.png': {'crop_finger': [356, 1541, 150, 1543],
#   'crop_backhand': [779, 1263, 1333, 1718],
#   'crop_fingerbackhand': [356, 1541, 150, 1718],
#   'crop_arm': [801, 1256, 1521, 2047]},
#  'image1661738561744.png': {'crop_finger': [432, 1708, 163, 1563],
#   'crop_backhand': [740, 1225, 1343, 1728],
#   'crop_fingerbackhand': [432, 1708, 163, 1728],
#   'crop_arm': [732, 1194, 1536, 2047]},
#  'image1661821466164.png': {'crop_finger': [414, 1517, 257, 1482],
#   'crop_backhand': [804, 1232, 1285, 1606],
#   'crop_fingerbackhand': [414, 1517, 257, 1606],
#   'crop_arm': [809, 1248, 1420, 2047]},
#  'image1661821482292.png': {'crop_finger': [520, 1645, 261, 1491],
#   'crop_backhand': [774, 1207, 1274, 1610],
#   'crop_fingerbackhand': [520, 1645, 261, 1610],
#   'crop_arm': [725, 1179, 1439, 2047]},
#  'image1661821684506.png': {'crop_finger': [449, 1528, 186, 1391],
#   'crop_backhand': [832, 1265, 1183, 1517],
#   'crop_fingerbackhand': [449, 1528, 186, 1517],
#   'crop_arm': [864, 1279, 1339, 2047]},
#  'image1661821711879.png': {'crop_finger': [472, 1676, 247, 1454],
#   'crop_backhand': [812, 1242, 1250, 1588],
#   'crop_fingerbackhand': [472, 1676, 247, 1588],
#   'crop_arm': [781, 1200, 1414, 2047]},
#  'image1661821775105.png': {'crop_finger': [351, 1535, 227, 1481],
#   'crop_backhand': [774, 1239, 1275, 1655],
#   'crop_fingerbackhand': [351, 1535, 227, 1655],
#   'crop_arm': [777, 1271, 1454, 2047]},
#  'image1661821802814.png': {'crop_finger': [529, 1622, 214, 1453],
#   'crop_backhand': [774, 1255, 1264, 1641],
#   'crop_fingerbackhand': [529, 1622, 214, 1641],
#   'crop_arm': [740, 1228, 1442, 2047]},
#  'image1661821925422.png': {'crop_finger': [378, 1539, 191, 1479],
#   'crop_backhand': [770, 1232, 1268, 1595],
#   'crop_fingerbackhand': [378, 1539, 191, 1595],
#   'crop_arm': [777, 1231, 1406, 2047]},
#  'image1661821945630.png': {'crop_finger': [468, 1756, 134, 1434],
#   'crop_backhand': [757, 1219, 1201, 1542],
#   'crop_fingerbackhand': [468, 1756, 134, 1542],
#   'crop_arm': [746, 1194, 1358, 2047]},
#  'image1661821994264.png': {'crop_finger': [350, 1554, 252, 1536],
#   'crop_backhand': [771, 1227, 1308, 1669],
#   'crop_fingerbackhand': [350, 1554, 252, 1669],
#   'crop_arm': [782, 1222, 1495, 2047]},
#  'image1661822012289.png': {'crop_finger': [490, 1730, 220, 1470],
#   'crop_backhand': [824, 1291, 1273, 1631],
#   'crop_fingerbackhand': [490, 1730, 220, 1631],
#   'crop_arm': [822, 1267, 1448, 2047]},
#  'image1661822075331.png': {'crop_finger': [517, 1552, 271, 1420],
#   'crop_backhand': [773, 1211, 1272, 1623],
#   'crop_fingerbackhand': [517, 1552, 271, 1623],
#   'crop_arm': [782, 1212, 1426, 2047]},
#  'image1661822091755.png': {'crop_finger': [516, 1486, 285, 1448],
#   'crop_backhand': [797, 1245, 1300, 1649],
#   'crop_fingerbackhand': [516, 1486, 285, 1649],
#   'crop_arm': [788, 1217, 1460, 2047]},
#  'image1661822623891.png': {'crop_finger': [273, 1536, 28, 1400],
#   'crop_backhand': [754, 1252, 1166, 1545],
#   'crop_fingerbackhand': [273, 1536, 28, 1545],
#   'crop_arm': [768, 1248, 1354, 2047]},
#  'image1661822638602.png': {'crop_finger': [445, 1783, 85, 1429],
#   'crop_backhand': [750, 1264, 1202, 1601],
#   'crop_fingerbackhand': [445, 1783, 85, 1601],
#   'crop_arm': [725, 1222, 1406, 2047]},
#  'image1661823124435.png': {'crop_finger': [308, 1567, 132, 1419],
#   'crop_backhand': [727, 1226, 1226, 1608],
#   'crop_fingerbackhand': [308, 1567, 132, 1608],
#   'crop_arm': [763, 1229, 1412, 2047]},
#  'image1661823153715.png': {'crop_finger': [442, 1798, 189, 1499],
#   'crop_backhand': [794, 1301, 1295, 1679],
#   'crop_fingerbackhand': [442, 1798, 189, 1679],
#   'crop_arm': [792, 1260, 1483, 2047]},
#  'image1661823372660.png': {'crop_finger': [488, 1542, 259, 1472],
#   'crop_backhand': [757, 1212, 1304, 1650],
#   'crop_fingerbackhand': [488, 1542, 259, 1650],
#   'crop_arm': [773, 1208, 1458, 2047]},
#  'image1661823399448.png': {'crop_finger': [458, 1534, 264, 1498],
#   'crop_backhand': [785, 1256, 1329, 1672],
#   'crop_fingerbackhand': [458, 1534, 264, 1672],
#   'crop_arm': [772, 1216, 1489, 2047]},
#  'image1661823451031.png': {'crop_finger': [396, 1545, 183, 1464],
#   'crop_backhand': [755, 1200, 1275, 1612],
#   'crop_fingerbackhand': [396, 1545, 183, 1612],
#   'crop_arm': [766, 1226, 1416, 2047]},
#  'image1661823478846.png': {'crop_finger': [527, 1668, 180, 1470],
#   'crop_backhand': [776, 1218, 1268, 1610],
#   'crop_fingerbackhand': [527, 1668, 180, 1610],
#   'crop_arm': [766, 1209, 1404, 2047]},
#  'image1661823719144.png': {'crop_finger': [474, 1542, 276, 1489],
#   'crop_backhand': [774, 1212, 1312, 1638],
#   'crop_fingerbackhand': [474, 1542, 276, 1638],
#   'crop_arm': [815, 1278, 1469, 2047]},
#  'image1661823735980.png': {'crop_finger': [528, 1601, 283, 1488],
#   'crop_backhand': [818, 1251, 1312, 1648],
#   'crop_fingerbackhand': [528, 1601, 283, 1648],
#   'crop_arm': [778, 1209, 1467, 2047]},
#  'image1661823784327.png': {'crop_finger': [451, 1519, 277, 1478],
#   'crop_backhand': [793, 1238, 1312, 1654],
#   'crop_fingerbackhand': [451, 1519, 277, 1654],
#   'crop_arm': [826, 1236, 1479, 2047]},
#  'image1661823804874.png': {'crop_finger': [543, 1588, 226, 1422],
#   'crop_backhand': [762, 1210, 1246, 1588],
#   'crop_fingerbackhand': [543, 1588, 226, 1588],
#   'crop_arm': [760, 1171, 1410, 2047]},
#  'image1661823869105.png': {'crop_finger': [486, 1577, 229, 1487],
#   'crop_backhand': [770, 1212, 1295, 1616],
#   'crop_fingerbackhand': [486, 1577, 229, 1616],
#   'crop_arm': [789, 1223, 1447, 2047]},
#  'image1661823886365.png': {'crop_finger': [418, 1558, 242, 1474],
#   'crop_backhand': [778, 1218, 1292, 1623],
#   'crop_fingerbackhand': [418, 1558, 242, 1623],
#   'crop_arm': [773, 1186, 1441, 2047]},
#  'image1661823951053.png': {'crop_finger': [510, 1526, 209, 1470],
#   'crop_backhand': [779, 1255, 1284, 1634],
#   'crop_fingerbackhand': [510, 1526, 209, 1634],
#   'crop_arm': [823, 1278, 1466, 2047]},
#  'image1661823978298.png': {'crop_finger': [513, 1593, 219, 1469],
#   'crop_backhand': [819, 1287, 1281, 1660],
#   'crop_fingerbackhand': [513, 1593, 219, 1660],
#   'crop_arm': [781, 1252, 1491, 2047]},
#  'image1661824839597.png': {'crop_finger': [399, 1552, 183, 1426],
#   'crop_backhand': [802, 1260, 1212, 1553],
#   'crop_fingerbackhand': [399, 1552, 183, 1553],
#   'crop_arm': [826, 1257, 1379, 2047]},
#  'image1661824857100.png': {'crop_finger': [454, 1669, 193, 1416],
#   'crop_backhand': [792, 1249, 1209, 1550],
#   'crop_fingerbackhand': [454, 1669, 193, 1550],
#   'crop_arm': [781, 1215, 1382, 2047]},
#  'image1661824948243.png': {'crop_finger': [282, 1553, 95, 1423],
#   'crop_backhand': [704, 1189, 1212, 1574],
#   'crop_fingerbackhand': [282, 1553, 95, 1574],
#   'crop_arm': [729, 1187, 1393, 2047]},
#  'image1661824974619.png': {'crop_finger': [473, 1792, 110, 1428],
#   'crop_backhand': [815, 1308, 1235, 1594],
#   'crop_fingerbackhand': [473, 1792, 110, 1594],
#   'crop_arm': [804, 1262, 1410, 2047]},
#  'image1661825019084.png': {'crop_finger': [504, 1555, 155, 1410],
#   'crop_backhand': [765, 1218, 1236, 1565],
#   'crop_fingerbackhand': [504, 1555, 155, 1565],
#   'crop_arm': [790, 1214, 1382, 2047]},
#  'image1661825034811.png': {'crop_finger': [492, 1568, 232, 1500],
#   'crop_backhand': [792, 1238, 1318, 1641],
#   'crop_fingerbackhand': [492, 1568, 232, 1641],
#   'crop_arm': [772, 1209, 1456, 2047]},
#  'image1661907643003.png': {'crop_finger': [416, 1488, 177, 1462],
#   'crop_backhand': [769, 1247, 1307, 1654],
#   'crop_fingerbackhand': [416, 1488, 177, 1654],
#   'crop_arm': [790, 1235, 1482, 2047]},
#  'image1661907663786.png': {'crop_finger': [531, 1545, 160, 1438],
#   'crop_backhand': [745, 1220, 1266, 1623],
#   'crop_fingerbackhand': [531, 1545, 160, 1623],
#   'crop_arm': [750, 1191, 1435, 2047]},
#  'image1661907717648.png': {'crop_finger': [322, 1534, 131, 1469],
#   'crop_backhand': [736, 1230, 1247, 1631],
#   'crop_fingerbackhand': [322, 1534, 131, 1631],
#   'crop_arm': [768, 1264, 1447, 2047]},
#  'image1661907733328.png': {'crop_finger': [427, 1712, 196, 1523],
#   'crop_backhand': [758, 1252, 1292, 1701],
#   'crop_fingerbackhand': [427, 1712, 196, 1701],
#   'crop_arm': [732, 1217, 1507, 2047]},
#  'image1661907834003.png': {'crop_finger': [376, 1488, 201, 1350],
#   'crop_backhand': [765, 1193, 1178, 1481],
#   'crop_fingerbackhand': [376, 1488, 201, 1481],
#   'crop_arm': [791, 1197, 1310, 2047]},
#  'image1661907848327.png': {'crop_finger': [544, 1608, 160, 1306],
#   'crop_backhand': [785, 1201, 1127, 1437],
#   'crop_fingerbackhand': [544, 1608, 160, 1437],
#   'crop_arm': [777, 1174, 1247, 2047]},
#  'image1661907993946.png': {'crop_finger': [422, 1523, 194, 1442],
#   'crop_backhand': [755, 1263, 1262, 1642],
#   'crop_fingerbackhand': [422, 1523, 194, 1642],
#   'crop_arm': [799, 1282, 1451, 2047]},
#  'image1661908013121.png': {'crop_finger': [443, 1603, 228, 1458],
#   'crop_backhand': [742, 1240, 1287, 1674],
#   'crop_fingerbackhand': [443, 1603, 228, 1674],
#   'crop_arm': [718, 1193, 1479, 2047]},
#  'image1661908066059.png': {'crop_finger': [436, 1554, 135, 1520],
#   'crop_backhand': [795, 1255, 1313, 1674],
#   'crop_fingerbackhand': [436, 1554, 135, 1674],
#   'crop_arm': [796, 1249, 1481, 2047]},
#  'image1661908082014.png': {'crop_finger': [471, 1616, 183, 1552],
#   'crop_backhand': [793, 1263, 1354, 1714],
#   'crop_fingerbackhand': [471, 1616, 183, 1714],
#   'crop_arm': [789, 1248, 1523, 2047]},
#  'image1661908159643.png': {'crop_finger': [408, 1557, 165, 1432],
#   'crop_backhand': [760, 1212, 1257, 1591],
#   'crop_fingerbackhand': [408, 1557, 165, 1591],
#   'crop_arm': [780, 1202, 1397, 2047]},
#  'image1661908185790.png': {'crop_finger': [503, 1611, 230, 1503],
#   'crop_backhand': [748, 1199, 1315, 1654],
#   'crop_fingerbackhand': [503, 1611, 230, 1654],
#   'crop_arm': [743, 1168, 1464, 2047]},
#  'image1661908251222.png': {'crop_finger': [336, 1542, 160, 1469],
#   'crop_backhand': [773, 1263, 1238, 1602],
#   'crop_fingerbackhand': [336, 1542, 160, 1602],
#   'crop_arm': [805, 1259, 1422, 2047]},
#  'image1661908266164.png': {'crop_finger': [488, 1750, 158, 1470],
#   'crop_backhand': [733, 1241, 1254, 1620],
#   'crop_fingerbackhand': [488, 1750, 158, 1620],
#   'crop_arm': [714, 1194, 1436, 2047]},
#  'image1661908331939.png': {'crop_finger': [480, 1507, 238, 1496],
#   'crop_backhand': [774, 1217, 1325, 1656],
#   'crop_fingerbackhand': [480, 1507, 238, 1656],
#   'crop_arm': [804, 1223, 1477, 2047]},
#  'image1661908355715.png': {'crop_finger': [507, 1589, 204, 1473],
#   'crop_backhand': [791, 1231, 1296, 1632],
#   'crop_fingerbackhand': [507, 1589, 204, 1632],
#   'crop_arm': [791, 1205, 1448, 2047]},
#  'image1661908653923.png': {'crop_finger': [438, 1559, 209, 1427],
#   'crop_backhand': [767, 1233, 1212, 1574],
#   'crop_fingerbackhand': [438, 1559, 209, 1574],
#   'crop_arm': [778, 1243, 1385, 2047]},
#  'image1661908672926.png': {'crop_finger': [440, 1650, 242, 1457],
#   'crop_backhand': [763, 1232, 1245, 1606],
#   'crop_fingerbackhand': [440, 1650, 242, 1606],
#   'crop_arm': [754, 1212, 1415, 2047]},
#  'image1661908761598.png': {'crop_finger': [439, 1595, 259, 1532],
#   'crop_backhand': [791, 1226, 1351, 1672],
#   'crop_fingerbackhand': [439, 1595, 259, 1672],
#   'crop_arm': [807, 1229, 1507, 2047]},
#  'image1661908778667.png': {'crop_finger': [491, 1610, 182, 1473],
#   'crop_backhand': [777, 1208, 1276, 1606],
#   'crop_fingerbackhand': [491, 1610, 182, 1606],
#   'crop_arm': [786, 1194, 1430, 2047]},
#  'image1661908857057.png': {'crop_finger': [449, 1503, 245, 1438],
#   'crop_backhand': [823, 1242, 1246, 1580],
#   'crop_fingerbackhand': [449, 1503, 245, 1580],
#   'crop_arm': [842, 1269, 1390, 2047]},
#  'image1661908886446.png': {'crop_finger': [537, 1636, 311, 1504],
#   'crop_backhand': [808, 1215, 1300, 1641],
#   'crop_fingerbackhand': [537, 1636, 311, 1641],
#   'crop_arm': [778, 1201, 1448, 2047]},
#  'image1661908973880.png': {'crop_finger': [284, 1620, 85, 1480],
#   'crop_backhand': [734, 1248, 1259, 1640],
#   'crop_fingerbackhand': [284, 1620, 85, 1640],
#   'crop_arm': [797, 1281, 1469, 2047]},
#  'image1661909071872.png': {'crop_finger': [470, 1766, 136, 1506],
#   'crop_backhand': [831, 1343, 1309, 1695],
#   'crop_fingerbackhand': [470, 1766, 136, 1695],
#   'crop_arm': [795, 1289, 1504, 2047]},
#  'image1661910199152.png': {'crop_finger': [429, 1482, 185, 1452],
#   'crop_backhand': [752, 1217, 1237, 1619],
#   'crop_fingerbackhand': [429, 1482, 185, 1619],
#   'crop_arm': [770, 1219, 1433, 2047]},
#  'image1661910238659.png': {'crop_finger': [487, 1577, 192, 1459],
#   'crop_backhand': [782, 1254, 1242, 1634],
#   'crop_fingerbackhand': [487, 1577, 192, 1634],
#   'crop_arm': [791, 1235, 1436, 2047]},
#  'image1661910959304.png': {'crop_finger': [446, 1447, 297, 1459],
#   'crop_backhand': [782, 1192, 1279, 1597],
#   'crop_fingerbackhand': [446, 1447, 297, 1597],
#   'crop_arm': [797, 1202, 1430, 2047]},
#  'image1661910986113.png': {'crop_finger': [547, 1501, 306, 1452],
#   'crop_backhand': [833, 1246, 1275, 1619],
#   'crop_fingerbackhand': [547, 1501, 306, 1619],
#   'crop_arm': [825, 1225, 1442, 2047]},
#  'image1661911030089.png': {'crop_finger': [415, 1492, 186, 1483],
#   'crop_backhand': [762, 1219, 1311, 1670],
#   'crop_fingerbackhand': [415, 1492, 186, 1670],
#   'crop_arm': [768, 1211, 1465, 2047]},
#  'image1661911048126.png': {'crop_finger': [579, 1575, 222, 1497],
#   'crop_backhand': [782, 1245, 1334, 1695],
#   'crop_fingerbackhand': [579, 1575, 222, 1695],
#   'crop_arm': [776, 1219, 1495, 2047]},
#  'image1661911113575.png': {'crop_finger': [477, 1517, 250, 1487],
#   'crop_backhand': [802, 1272, 1286, 1643],
#   'crop_fingerbackhand': [477, 1517, 250, 1643],
#   'crop_arm': [843, 1284, 1466, 2047]},
#  'image1661911139753.png': {'crop_finger': [514, 1547, 214, 1425],
#   'crop_backhand': [791, 1249, 1252, 1609],
#   'crop_fingerbackhand': [514, 1547, 214, 1609],
#   'crop_arm': [773, 1218, 1423, 2047]},
#  'image1662339673237.png': {'crop_finger': [429, 1509, 332, 1634],
#   'crop_backhand': [747, 1239, 1451, 1813],
#   'crop_fingerbackhand': [429, 1509, 332, 1813],
#   'crop_arm': [768, 1235, 1624, 2047]},
#  'image1662339722889.png': {'crop_finger': [446, 1609, 173, 1470],
#   'crop_backhand': [784, 1270, 1275, 1644],
#   'crop_fingerbackhand': [446, 1609, 173, 1644],
#   'crop_arm': [790, 1256, 1449, 2047]},
#  'image1662339776115.png': {'crop_finger': [444, 1542, 253, 1480],
#   'crop_backhand': [838, 1315, 1270, 1626],
#   'crop_fingerbackhand': [444, 1542, 253, 1626],
#   'crop_arm': [868, 1314, 1440, 2047]},
#  'image1662339793561.png': {'crop_finger': [487, 1654, 291, 1524],
#   'crop_backhand': [729, 1198, 1308, 1674],
#   'crop_fingerbackhand': [487, 1654, 291, 1674],
#   'crop_arm': [708, 1166, 1487, 2047]},
#  'image1662339832272.png': {'crop_finger': [425, 1496, 239, 1437],
#   'crop_backhand': [743, 1191, 1251, 1584],
#   'crop_fingerbackhand': [425, 1496, 239, 1584],
#   'crop_arm': [776, 1202, 1409, 2047]},
#  'image1662339858518.png': {'crop_finger': [476, 1632, 299, 1504],
#   'crop_backhand': [814, 1261, 1312, 1653],
#   'crop_fingerbackhand': [476, 1632, 299, 1653],
#   'crop_arm': [807, 1234, 1461, 2047]},
#  'image1662339910471.png': {'crop_finger': [406, 1557, 202, 1424],
#   'crop_backhand': [765, 1225, 1213, 1571],
#   'crop_fingerbackhand': [406, 1557, 202, 1571],
#   'crop_arm': [794, 1247, 1383, 2047]},
#  'image1662339926546.png': {'crop_finger': [501, 1690, 220, 1459],
#   'crop_backhand': [814, 1272, 1236, 1593],
#   'crop_fingerbackhand': [501, 1690, 220, 1593],
#   'crop_arm': [793, 1248, 1395, 2047]},
#  'image1662340270441.png': {'crop_finger': [491, 1490, 290, 1480],
#   'crop_backhand': [799, 1225, 1310, 1631],
#   'crop_fingerbackhand': [491, 1490, 290, 1631],
#   'crop_arm': [826, 1233, 1461, 2047]},
#  'image1662340289452.png': {'crop_finger': [532, 1534, 248, 1427],
#   'crop_backhand': [803, 1224, 1261, 1592],
#   'crop_fingerbackhand': [532, 1534, 248, 1592],
#   'crop_arm': [793, 1197, 1412, 2047]},
#  'image1662340433669.png': {'crop_finger': [355, 1556, 229, 1457],
#   'crop_backhand': [730, 1185, 1291, 1619],
#   'crop_fingerbackhand': [355, 1556, 229, 1619],
#   'crop_arm': [763, 1216, 1440, 2047]},
#  'image1662340460163.png': {'crop_finger': [506, 1636, 173, 1398],
#   'crop_backhand': [826, 1281, 1222, 1566],
#   'crop_fingerbackhand': [506, 1636, 173, 1566],
#   'crop_arm': [787, 1233, 1384, 2047]},
#  'image1664154662622.png': {'crop_finger': [641, 1942, 247, 1397],
#   'crop_backhand': [665, 1093, 1051, 1501],
#   'crop_fingerbackhand': [641, 1942, 247, 1501],
#   'crop_arm': [625, 1110, 1312, 2047]},
#  'image1664154681702.png': {'crop_finger': [18, 1338, 228, 1357],
#   'crop_backhand': [862, 1296, 1016, 1462],
#   'crop_fingerbackhand': [18, 1338, 228, 1462],
#   'crop_arm': [843, 1322, 1280, 2047]},
#  'image1664154734422.png': {'crop_finger': [621, 1910, 301, 1455],
#   'crop_backhand': [739, 1162, 1136, 1571],
#   'crop_fingerbackhand': [621, 1910, 301, 1571],
#   'crop_arm': [707, 1171, 1397, 2047]},
#  'image1664154750085.png': {'crop_finger': [58, 1421, 176, 1353],
#   'crop_backhand': [834, 1265, 1033, 1464],
#   'crop_fingerbackhand': [58, 1421, 176, 1464],
#   'crop_arm': [824, 1291, 1294, 2047]},
#  'image1664154988975.png': {'crop_finger': [675, 1890, 250, 1330],
#   'crop_backhand': [778, 1162, 1048, 1431],
#   'crop_fingerbackhand': [675, 1890, 250, 1431],
#   'crop_arm': [754, 1199, 1261, 2047]},
#  'image1664155004523.png': {'crop_finger': [38, 1337, 391, 1376],
#   'crop_backhand': [875, 1256, 1072, 1456],
#   'crop_fingerbackhand': [38, 1337, 391, 1456],
#   'crop_arm': [830, 1278, 1286, 2047]},
#  'image1664155043861.png': {'crop_finger': [634, 1921, 187, 1404],
#   'crop_backhand': [723, 1167, 1108, 1530],
#   'crop_fingerbackhand': [634, 1921, 187, 1530],
#   'crop_arm': [724, 1171, 1361, 2047]},
#  'image1664155070330.png': {'crop_finger': [140, 1431, 141, 1386],
#   'crop_backhand': [858, 1302, 1074, 1510],
#   'crop_fingerbackhand': [140, 1431, 141, 1510],
#   'crop_arm': [869, 1310, 1335, 2047]},
#  'image1664155311840.png': {'crop_finger': [725, 1971, 278, 1403],
#   'crop_backhand': [780, 1203, 1093, 1503],
#   'crop_fingerbackhand': [725, 1971, 278, 1503],
#   'crop_arm': [767, 1209, 1314, 2047]},
#  'image1664155340191.png': {'crop_finger': [83, 1327, 241, 1394],
#   'crop_backhand': [805, 1231, 1110, 1509],
#   'crop_fingerbackhand': [83, 1327, 241, 1509],
#   'crop_arm': [777, 1226, 1336, 2047]},
#  'image1664155779711.png': {'crop_finger': [727, 1922, 344, 1375],
#   'crop_backhand': [746, 1173, 1055, 1480],
#   'crop_fingerbackhand': [727, 1922, 344, 1480],
#   'crop_arm': [730, 1163, 1303, 2047]},
#  'image1664155796443.png': {'crop_finger': [165, 1400, 375, 1464],
#   'crop_backhand': [891, 1322, 1166, 1586],
#   'crop_fingerbackhand': [165, 1400, 375, 1586],
#   'crop_arm': [884, 1333, 1407, 2047]},
#  'image1664155835486.png': {'crop_finger': [721, 1870, 203, 1333],
#   'crop_backhand': [757, 1148, 1049, 1453],
#   'crop_fingerbackhand': [721, 1870, 203, 1453],
#   'crop_arm': [721, 1123, 1262, 2047]},
#  'image1664155861738.png': {'crop_finger': [62, 1277, 336, 1439],
#   'crop_backhand': [802, 1192, 1137, 1546],
#   'crop_fingerbackhand': [62, 1277, 336, 1546],
#   'crop_arm': [802, 1214, 1362, 2047]},
#  'image1664155901562.png': {'crop_finger': [716, 1910, 346, 1453],
#   'crop_backhand': [785, 1197, 1192, 1603],
#   'crop_fingerbackhand': [716, 1910, 346, 1603],
#   'crop_arm': [763, 1210, 1422, 2047]},
#  'image1664155916129.png': {'crop_finger': [122, 1314, 253, 1387],
#   'crop_backhand': [843, 1259, 1108, 1523],
#   'crop_fingerbackhand': [122, 1314, 253, 1523],
#   'crop_arm': [822, 1272, 1343, 2047]},
#  'image1664155969209.png': {'crop_finger': [664, 1910, 144, 1338],
#   'crop_backhand': [737, 1170, 1052, 1462],
#   'crop_fingerbackhand': [664, 1910, 144, 1462],
#   'crop_arm': [723, 1164, 1276, 2047]},
#  'image1664155987422.png': {'crop_finger': [146, 1343, 224, 1422],
#   'crop_backhand': [869, 1289, 1146, 1556],
#   'crop_fingerbackhand': [146, 1343, 224, 1556],
#   'crop_arm': [869, 1308, 1359, 2047]},
#  'image1664156791534.png': {'crop_finger': [692, 1909, 285, 1338],
#   'crop_backhand': [735, 1155, 1048, 1450],
#   'crop_fingerbackhand': [692, 1909, 285, 1450],
#   'crop_arm': [746, 1183, 1290, 2047]},
#  'image1664156819527.png': {'crop_finger': [122, 1314, 292, 1364],
#   'crop_backhand': [857, 1272, 1081, 1478],
#   'crop_fingerbackhand': [122, 1314, 292, 1478],
#   'crop_arm': [848, 1266, 1306, 2047]},
#  'image1664156885740.png': {'crop_finger': [715, 1899, 269, 1362],
#   'crop_backhand': [783, 1204, 1083, 1483],
#   'crop_fingerbackhand': [715, 1899, 269, 1483],
#   'crop_arm': [763, 1199, 1296, 2047]},
#  'image1664156902082.png': {'crop_finger': [224, 1398, 324, 1450],
#   'crop_backhand': [911, 1337, 1183, 1578],
#   'crop_fingerbackhand': [224, 1398, 324, 1578],
#   'crop_arm': [910, 1338, 1394, 2047]},
#  'image1664156956152.png': {'crop_finger': [711, 1894, 127, 1258],
#   'crop_backhand': [749, 1163, 982, 1382],
#   'crop_fingerbackhand': [711, 1894, 127, 1382],
#   'crop_arm': [734, 1155, 1204, 2047]},
#  'image1664156981600.png': {'crop_finger': [129, 1325, 191, 1314],
#   'crop_backhand': [844, 1263, 1053, 1445],
#   'crop_fingerbackhand': [129, 1325, 191, 1445],
#   'crop_arm': [841, 1280, 1267, 2047]},
#  'image1664157014295.png': {'crop_finger': [736, 1937, 304, 1322],
#   'crop_backhand': [767, 1163, 1022, 1421],
#   'crop_fingerbackhand': [736, 1937, 304, 1421],
#   'crop_arm': [758, 1167, 1251, 2047]},
#  'image1664157036946.png': {'crop_finger': [105, 1320, 363, 1411],
#   'crop_backhand': [861, 1260, 1109, 1513],
#   'crop_fingerbackhand': [105, 1320, 363, 1513],
#   'crop_arm': [854, 1262, 1340, 2047]},
#  'image1664157160259.png': {'crop_finger': [695, 1965, 214, 1376],
#   'crop_backhand': [738, 1158, 1059, 1480],
#   'crop_fingerbackhand': [695, 1965, 214, 1480],
#   'crop_arm': [697, 1153, 1294, 2047]},
#  'image1664157181373.png': {'crop_finger': [99, 1391, 203, 1374],
#   'crop_backhand': [903, 1324, 1058, 1476],
#   'crop_fingerbackhand': [99, 1391, 203, 1476],
#   'crop_arm': [897, 1352, 1283, 2047]},
#  'image1664157243138.png': {'crop_finger': [656, 1951, 303, 1440],
#   'crop_backhand': [714, 1158, 1123, 1569],
#   'crop_fingerbackhand': [656, 1951, 303, 1569],
#   'crop_arm': [707, 1158, 1360, 2047]},
#  'image1664157262497.png': {'crop_finger': [0, 1362, 295, 1380],
#   'crop_backhand': [846, 1278, 1050, 1499],
#   'crop_fingerbackhand': [0, 1362, 295, 1499],
#   'crop_arm': [860, 1289, 1290, 2047]},
#  'image1664157316352.png': {'crop_finger': [695, 1872, 495, 1451],
#   'crop_backhand': [721, 1120, 1135, 1537],
#   'crop_fingerbackhand': [695, 1872, 495, 1537],
#   'crop_arm': [690, 1098, 1344, 2047]},
#  'image1664157343885.png': {'crop_finger': [129, 1275, 407, 1473],
#   'crop_backhand': [848, 1253, 1154, 1558],
#   'crop_fingerbackhand': [129, 1275, 407, 1558],
#   'crop_arm': [872, 1270, 1360, 2047]},
#  'image1664157383539.png': {'crop_finger': [702, 1878, 371, 1377],
#   'crop_backhand': [727, 1122, 1085, 1472],
#   'crop_fingerbackhand': [702, 1878, 371, 1472],
#   'crop_arm': [712, 1132, 1298, 2047]},
#  'image1664157399991.png': {'crop_finger': [129, 1323, 308, 1329],
#   'crop_backhand': [877, 1272, 1040, 1428],
#   'crop_fingerbackhand': [129, 1323, 308, 1428],
#   'crop_arm': [846, 1275, 1255, 2047]},
#  'image1664240530775.png': {'crop_finger': [610, 1828, 346, 1451],
#   'crop_backhand': [671, 1079, 1121, 1556],
#   'crop_fingerbackhand': [610, 1828, 346, 1556],
#   'crop_arm': [639, 1075, 1351, 2047]},
#  'image1664240547272.png': {'crop_finger': [135, 1343, 271, 1421],
#   'crop_backhand': [870, 1277, 1102, 1529],
#   'crop_fingerbackhand': [135, 1343, 271, 1529],
#   'crop_arm': [867, 1295, 1330, 2047]},
#  'image1664240654049.png': {'crop_finger': [693, 1945, 259, 1432],
#   'crop_backhand': [756, 1157, 1130, 1531],
#   'crop_fingerbackhand': [693, 1945, 259, 1531],
#   'crop_arm': [733, 1179, 1359, 2047]},
#  'image1664240669924.png': {'crop_finger': [112, 1349, 223, 1395],
#   'crop_backhand': [861, 1267, 1117, 1509],
#   'crop_fingerbackhand': [112, 1349, 223, 1509],
#   'crop_arm': [815, 1273, 1339, 2047]},
#  'image1664240709270.png': {'crop_finger': [613, 1830, 275, 1399],
#   'crop_backhand': [710, 1136, 1090, 1523],
#   'crop_fingerbackhand': [613, 1830, 275, 1523],
#   'crop_arm': [681, 1145, 1340, 2047]},
#  'image1664240724225.png': {'crop_finger': [195, 1515, 231, 1393],
#   'crop_backhand': [865, 1309, 1129, 1537],
#   'crop_fingerbackhand': [195, 1515, 231, 1537],
#   'crop_arm': [865, 1319, 1338, 2047]},
#  'image1664240788212.png': {'crop_finger': [717, 1867, 309, 1392],
#   'crop_backhand': [754, 1174, 1108, 1513],
#   'crop_fingerbackhand': [717, 1867, 309, 1513],
#   'crop_arm': [751, 1180, 1339, 2047]},
#  'image1664240806931.png': {'crop_finger': [104, 1318, 180, 1319],
#   'crop_backhand': [848, 1267, 1015, 1426],
#   'crop_fingerbackhand': [104, 1318, 180, 1426],
#   'crop_arm': [798, 1257, 1261, 2047]},
# ...
#   'crop_arm': [807, 1245, 1269, 2047]},
#  'image1663032094569.png': {'crop_finger': [750, 1960, 305, 1357],
#   'crop_backhand': [779, 1200, 1031, 1459],
#   'crop_fingerbackhand': [750, 1960, 305, 1459],
#   'crop_arm': [765, 1201, 1267, 2047]},
#  'image1663032123062.png': {'crop_finger': [131, 1314, 328, 1391],
#   'crop_backhand': [842, 1267, 1075, 1495],
#   'crop_fingerbackhand': [131, 1314, 328, 1495],
#   'crop_arm': [831, 1265, 1317, 2047]},
#  'image1663032200123.png': {'crop_finger': [725, 1920, 290, 1365],
#   'crop_backhand': [781, 1170, 1051, 1467],
#   'crop_fingerbackhand': [725, 1920, 290, 1467],
#   'crop_arm': [746, 1161, 1262, 2047]},
#  'image1663032215672.png': {'crop_finger': [68, 1314, 241, 1302],
#   'crop_backhand': [785, 1179, 1005, 1417],
#   'crop_fingerbackhand': [68, 1314, 241, 1417],
#   'crop_arm': [778, 1193, 1222, 2047]},
#  'image1663032341274.png': {'crop_finger': [706, 1968, 152, 1323],
#   'crop_backhand': [771, 1227, 1016, 1445],
#   'crop_fingerbackhand': [706, 1968, 152, 1445],
#   'crop_arm': [759, 1244, 1254, 2047]},
#  'image1663032378555.png': {'crop_finger': [60, 1338, 159, 1328],
#   'crop_backhand': [780, 1237, 1040, 1455],
#   'crop_fingerbackhand': [60, 1338, 159, 1455],
#   'crop_arm': [745, 1232, 1284, 2047]},
#  'image1663032434284.png': {'crop_finger': [738, 2009, 216, 1307],
#   'crop_backhand': [858, 1305, 999, 1420],
#   'crop_fingerbackhand': [738, 2009, 216, 1420],
#   'crop_arm': [851, 1349, 1245, 2047]},
#  'image1663032464049.png': {'crop_finger': [59, 1364, 257, 1344],
#   'crop_backhand': [786, 1234, 1020, 1452],
#   'crop_fingerbackhand': [59, 1364, 257, 1452],
#   'crop_arm': [751, 1240, 1272, 2047]},
#  'image1663032787672.png': {'crop_finger': [666, 1911, 246, 1385],
#   'crop_backhand': [748, 1179, 1079, 1507],
#   'crop_fingerbackhand': [666, 1911, 246, 1507],
#   'crop_arm': [738, 1174, 1323, 2047]},
#  'image1663032815373.png': {'crop_finger': [125, 1377, 221, 1347],
#   'crop_backhand': [832, 1261, 1039, 1472],
#   'crop_fingerbackhand': [125, 1377, 221, 1472],
#   'crop_arm': [839, 1274, 1280, 2047]},
#  'image1663033739084.png': {'crop_finger': [647, 1968, 212, 1350],
#   'crop_backhand': [768, 1235, 1060, 1485],
#   'crop_fingerbackhand': [647, 1968, 212, 1485],
#   'crop_arm': [766, 1247, 1295, 2047]},
#  'image1663033766028.png': {'crop_finger': [0, 1360, 139, 1346],
#   'crop_backhand': [738, 1219, 1050, 1480],
#   'crop_fingerbackhand': [0, 1360, 139, 1480],
#   'crop_arm': [726, 1200, 1305, 2047]},
#  'image1663034114127.png': {'crop_finger': [772, 2003, 252, 1361],
#   'crop_backhand': [827, 1268, 1060, 1474],
#   'crop_fingerbackhand': [772, 2003, 252, 1474],
#   'crop_arm': [808, 1256, 1279, 2047]},
#  'image1663034135371.png': {'crop_finger': [135, 1375, 302, 1407],
#   'crop_backhand': [892, 1321, 1087, 1506],
#   'crop_fingerbackhand': [135, 1375, 302, 1506],
#   'crop_arm': [845, 1330, 1321, 2047]},
#  'image1663034183469.png': {'crop_finger': [716, 1968, 244, 1404],
#   'crop_backhand': [781, 1197, 1121, 1527],
#   'crop_fingerbackhand': [716, 1968, 244, 1527],
#   'crop_arm': [763, 1203, 1352, 2047]},
#  'image1663034202366.png': {'crop_finger': [76, 1453, 216, 1387],
#   'crop_backhand': [835, 1254, 1112, 1509],
#   'crop_fingerbackhand': [76, 1453, 216, 1509],
#   'crop_arm': [800, 1260, 1339, 2047]},
#  'image1663034255194.png': {'crop_finger': [739, 2047, 328, 1401],
#   'crop_backhand': [763, 1201, 1057, 1512],
#   'crop_fingerbackhand': [739, 2047, 328, 1512],
#   'crop_arm': [744, 1215, 1310, 2047]},
#  'image1663034294082.png': {'crop_finger': [48, 1349, 227, 1367],
#   'crop_backhand': [832, 1278, 1053, 1486],
#   'crop_fingerbackhand': [48, 1349, 227, 1486],
#   'crop_arm': [809, 1285, 1297, 2047]},
#  'image1663034350052.png': {'crop_finger': [697, 2035, 265, 1404],
#   'crop_backhand': [754, 1180, 1065, 1503],
#   'crop_fingerbackhand': [697, 2035, 265, 1503],
#   'crop_arm': [712, 1217, 1307, 2047]},
#  'image1663034378702.png': {'crop_finger': [8, 1405, 278, 1407],
#   'crop_backhand': [825, 1264, 1075, 1512],
#   'crop_fingerbackhand': [8, 1405, 278, 1512],
#   'crop_arm': [816, 1291, 1297, 2047]},
#  'image1663034430558.png': {'crop_finger': [641, 1947, 281, 1398],
#   'crop_backhand': [747, 1184, 1094, 1522],
#   'crop_fingerbackhand': [641, 1947, 281, 1522],
#   'crop_arm': [739, 1196, 1353, 2047]},
#  'image1663034460436.png': {'crop_finger': [50, 1402, 233, 1391],
#   'crop_backhand': [790, 1239, 1085, 1519],
#   'crop_fingerbackhand': [50, 1402, 233, 1519],
#   'crop_arm': [789, 1249, 1340, 2047]},
#  'image1663035050652.png': {'crop_finger': [724, 2032, 216, 1329],
#   'crop_backhand': [780, 1203, 1007, 1431],
#   'crop_fingerbackhand': [724, 2032, 216, 1431],
#   'crop_arm': [756, 1203, 1256, 2047]},
#  'image1663035076575.png': {'crop_finger': [73, 1419, 227, 1396],
#   'crop_backhand': [847, 1274, 1102, 1500],
#   'crop_fingerbackhand': [73, 1419, 227, 1500],
#   'crop_arm': [804, 1273, 1345, 2047]},
#  'image1663035116382.png': {'crop_finger': [708, 1945, 315, 1358],
#   'crop_backhand': [783, 1185, 1065, 1468],
#   'crop_fingerbackhand': [708, 1945, 315, 1468],
#   'crop_arm': [745, 1184, 1273, 2047]},
#  'image1663035143421.png': {'crop_finger': [210, 1406, 259, 1355],
#   'crop_backhand': [837, 1246, 1087, 1476],
#   'crop_fingerbackhand': [210, 1406, 259, 1476],
#   'crop_arm': [822, 1262, 1291, 2047]},
#  'image1663117163557.png': {'crop_finger': [745, 1923, 289, 1354],
#   'crop_backhand': [780, 1180, 1048, 1453],
#   'crop_fingerbackhand': [745, 1923, 289, 1453],
#   'crop_arm': [762, 1170, 1266, 2047]},
#  'image1663117191552.png': {'crop_finger': [141, 1379, 245, 1361],
#   'crop_backhand': [840, 1240, 1061, 1468],
#   'crop_fingerbackhand': [141, 1379, 245, 1468],
#   'crop_arm': [800, 1246, 1278, 2047]},
#  'image1663117343870.png': {'crop_finger': [744, 1930, 304, 1399],
#   'crop_backhand': [785, 1184, 1103, 1507],
#   'crop_fingerbackhand': [744, 1930, 304, 1507],
#   'crop_arm': [761, 1181, 1335, 2047]},
#  'image1663117371313.png': {'crop_finger': [172, 1382, 401, 1457],
#   'crop_backhand': [876, 1270, 1170, 1565],
#   'crop_fingerbackhand': [172, 1382, 401, 1565],
#   'crop_arm': [891, 1299, 1390, 2047]},
#  'image1663117424196.png': {'crop_finger': [656, 1937, 235, 1322],
#   'crop_backhand': [700, 1140, 1025, 1441],
#   'crop_fingerbackhand': [656, 1937, 235, 1441],
#   'crop_arm': [689, 1158, 1269, 2047]},
#  'image1663117441830.png': {'crop_finger': [98, 1396, 253, 1401],
#   'crop_backhand': [840, 1282, 1094, 1522],
#   'crop_fingerbackhand': [98, 1396, 253, 1522],
#   'crop_arm': [833, 1284, 1350, 2047]},
#  'image1663117541589.png': {'crop_finger': [701, 1927, 349, 1428],
#   'crop_backhand': [724, 1122, 1112, 1520],
#   'crop_fingerbackhand': [701, 1927, 349, 1520],
#   'crop_arm': [688, 1115, 1331, 2047]},
#  'image1663117559768.png': {'crop_finger': [174, 1411, 263, 1379],
#   'crop_backhand': [887, 1297, 1084, 1493],
#   'crop_fingerbackhand': [174, 1411, 263, 1493],
#   'crop_arm': [866, 1317, 1317, 2047]},
#  'image1663117636696.png': {'crop_finger': [646, 1903, 372, 1408],
#   'crop_backhand': [696, 1159, 1063, 1531],
#   'crop_fingerbackhand': [646, 1903, 372, 1531],
#   'crop_arm': [679, 1154, 1345, 2047]},
#  'image1663117652471.png': {'crop_finger': [98, 1387, 350, 1410],
#   'crop_backhand': [856, 1320, 1072, 1535],
#   'crop_fingerbackhand': [98, 1387, 350, 1535],
#   'crop_arm': [857, 1324, 1360, 2047]},
#  'image1663117714293.png': {'crop_finger': [706, 1895, 384, 1345],
#   'crop_backhand': [745, 1127, 1063, 1457],
#   'crop_fingerbackhand': [706, 1895, 384, 1457],
#   'crop_arm': [709, 1128, 1280, 2047]},
#  'image1663117733450.png': {'crop_finger': [172, 1361, 236, 1299],
#   'crop_backhand': [871, 1266, 1031, 1419],
#   'crop_fingerbackhand': [172, 1361, 236, 1419],
#   'crop_arm': [801, 1269, 1255, 2047]},
#  'image1663117797044.png': {'crop_finger': [714, 1994, 283, 1360],
#   'crop_backhand': [745, 1117, 1039, 1446],
#   'crop_fingerbackhand': [714, 1994, 283, 1446],
#   'crop_arm': [697, 1102, 1259, 2047]},
#  'image1663117823066.png': {'crop_finger': [52, 1322, 319, 1480],
#   'crop_backhand': [863, 1262, 1165, 1571],
#   'crop_fingerbackhand': [52, 1322, 319, 1571],
#   'crop_arm': [876, 1278, 1393, 2047]},
#  'image1663117894735.png': {'crop_finger': [709, 2001, 414, 1386],
#   'crop_backhand': [745, 1148, 1035, 1471],
#   'crop_fingerbackhand': [709, 2001, 414, 1471],
#   'crop_arm': [710, 1151, 1284, 2047]},
#  'image1663117920899.png': {'crop_finger': [94, 1366, 365, 1477],
#   'crop_backhand': [841, 1260, 1152, 1582],
#   'crop_fingerbackhand': [94, 1366, 365, 1582],
#   'crop_arm': [839, 1283, 1389, 2047]},
#  'image1663117976084.png': {'crop_finger': [688, 2010, 249, 1420],
#   'crop_backhand': [727, 1192, 1068, 1518],
#   'crop_fingerbackhand': [688, 2010, 249, 1518],
#   'crop_arm': [695, 1165, 1324, 2047]},
#  'image1663117993481.png': {'crop_finger': [127, 1432, 201, 1422],
#   'crop_backhand': [884, 1360, 1093, 1536],
#   'crop_fingerbackhand': [127, 1432, 201, 1536],
#   'crop_arm': [884, 1373, 1353, 2047]},
#  'image1663118048219.png': {'crop_finger': [696, 1979, 434, 1425],
#   'crop_backhand': [744, 1131, 1100, 1499],
#   'crop_fingerbackhand': [696, 1979, 434, 1499],
#   'crop_arm': [716, 1128, 1319, 2047]},
#  'image1663118074508.png': {'crop_finger': [146, 1400, 322, 1389],
#   'crop_backhand': [946, 1332, 1066, 1458],
#   'crop_fingerbackhand': [146, 1400, 322, 1458],
#   'crop_arm': [917, 1352, 1285, 2047]},
#  'image1663118126334.png': {'crop_finger': [728, 1969, 451, 1413],
#   'crop_backhand': [778, 1164, 1112, 1505],
#   'crop_fingerbackhand': [728, 1969, 451, 1505],
#   'crop_arm': [748, 1155, 1318, 2047]},
#  'image1663118153145.png': {'crop_finger': [75, 1317, 346, 1411],
#   'crop_backhand': [839, 1230, 1136, 1515],
#   'crop_fingerbackhand': [75, 1317, 346, 1515],
#   'crop_arm': [806, 1236, 1342, 2047]},
#  'image1663118367923.png': {'crop_finger': [694, 1790, 380, 1349],
#   'crop_backhand': [750, 1126, 1048, 1436],
#   'crop_fingerbackhand': [694, 1790, 380, 1436],
#   'crop_arm': [737, 1131, 1253, 2047]},
#  'image1663118386163.png': {'crop_finger': [244, 1312, 392, 1417],
#   'crop_backhand': [885, 1272, 1116, 1505],
#   'crop_fingerbackhand': [244, 1312, 392, 1505],
#   'crop_arm': [827, 1261, 1333, 2047]},
#  'image1663118622397.png': {'crop_finger': [695, 1958, 378, 1469],
#   'crop_backhand': [721, 1124, 1147, 1576],
#   'crop_fingerbackhand': [695, 1958, 378, 1576],
#   'crop_arm': [691, 1117, 1373, 2047]},
#  'image1663118652155.png': {'crop_finger': [68, 1293, 300, 1458],
#   'crop_backhand': [858, 1263, 1127, 1558],
#   'crop_fingerbackhand': [68, 1293, 300, 1558],
#   'crop_arm': [839, 1267, 1366, 2047]},
#  'image1663118720815.png': {'crop_finger': [751, 1928, 229, 1386],
#   'crop_backhand': [802, 1212, 1110, 1504],
#   'crop_fingerbackhand': [751, 1928, 229, 1504],
#   'crop_arm': [798, 1218, 1327, 2047]},
#  'image1663118747900.png': {'crop_finger': [182, 1327, 272, 1417],
#   'crop_backhand': [815, 1232, 1157, 1553],
#   'crop_fingerbackhand': [182, 1327, 272, 1553],
#   'crop_arm': [787, 1224, 1382, 2047]},
#  'image1663118800633.png': {'crop_finger': [766, 2011, 429, 1456],
#   'crop_backhand': [820, 1216, 1166, 1563],
#   'crop_fingerbackhand': [766, 2011, 429, 1563],
#   'crop_arm': [800, 1219, 1376, 2047]},
#  'image1663118841222.png': {'crop_finger': [142, 1368, 270, 1419],
#   'crop_backhand': [890, 1295, 1140, 1533],
#   'crop_fingerbackhand': [142, 1368, 270, 1533],
#   'crop_arm': [868, 1303, 1351, 2047]},
#  'image1663119447884.png': {'crop_finger': [682, 2021, 205, 1383],
#   'crop_backhand': [746, 1174, 1047, 1496],
#   'crop_fingerbackhand': [682, 2021, 205, 1496],
#   'crop_arm': [716, 1186, 1304, 2047]},
#  'image1663119474248.png': {'crop_finger': [60, 1444, 249, 1489],
#   'crop_backhand': [823, 1266, 1170, 1604],
#   'crop_fingerbackhand': [60, 1444, 249, 1604],
#   'crop_arm': [824, 1284, 1415, 2047]},
#  'image1663119739211.png': {'crop_finger': [688, 1925, 269, 1431],
#   'crop_backhand': [712, 1117, 1119, 1534],
#   'crop_fingerbackhand': [688, 1925, 269, 1534],
#   'crop_arm': [689, 1104, 1359, 2047]},
#  'image1663119766056.png': {'crop_finger': [76, 1321, 323, 1497],
#   'crop_backhand': [831, 1246, 1205, 1615],
#   'crop_fingerbackhand': [76, 1321, 323, 1615],
#   'crop_arm': [836, 1258, 1435, 2047]},
#  'image1663119807498.png': {'crop_finger': [663, 2017, 327, 1400],
#   'crop_backhand': [734, 1177, 1060, 1497],
#   'crop_fingerbackhand': [663, 2017, 327, 1497],
#   'crop_arm': [726, 1216, 1321, 2047]},
#  'image1663119833904.png': {'crop_finger': [22, 1368, 325, 1438],
#   'crop_backhand': [866, 1300, 1093, 1533],
#   'crop_fingerbackhand': [22, 1368, 325, 1533],
#   'crop_arm': [832, 1307, 1351, 2047]},
#  'image1663119987665.png': {'crop_finger': [674, 1994, 230, 1358],
#   'crop_backhand': [762, 1172, 1045, 1479],
#   'crop_fingerbackhand': [674, 1994, 230, 1479],
#   'crop_arm': [719, 1175, 1281, 2047]},
#  'image1663120015357.png': {'crop_finger': [83, 1412, 268, 1449],
#   'crop_backhand': [852, 1275, 1147, 1569],
#   'crop_fingerbackhand': [83, 1412, 268, 1569],
#   'crop_arm': [860, 1319, 1375, 2047]},
#  'image1663120192350.png': {'crop_finger': [664, 1976, 206, 1324],
#   'crop_backhand': [727, 1183, 1001, 1460],
#   'crop_fingerbackhand': [664, 1976, 206, 1460],
#   'crop_arm': [694, 1162, 1255, 2047]},
#  'image1663120209081.png': {'crop_finger': [83, 1388, 166, 1389],
#   'crop_backhand': [819, 1284, 1082, 1530],
#   'crop_fingerbackhand': [83, 1388, 166, 1530],
#   'crop_arm': [813, 1299, 1336, 2047]},
#  'image1663120273363.png': {'crop_finger': [653, 2047, 273, 1394],
#   'crop_backhand': [693, 1113, 1068, 1498],
#   'crop_fingerbackhand': [653, 2047, 273, 1498],
#   'crop_arm': [656, 1101, 1293, 2047]},
#  'image1663120303210.png': {'crop_finger': [0, 1368, 277, 1485],
#   'crop_backhand': [852, 1287, 1162, 1584],
#   'crop_fingerbackhand': [0, 1368, 277, 1584],
#   'crop_arm': [844, 1296, 1400, 2047]},
#  'image1663120705408.png': {'crop_finger': [692, 2000, 284, 1444],
#   'crop_backhand': [767, 1216, 1134, 1589],
#   'crop_fingerbackhand': [692, 2000, 284, 1589],
#   'crop_arm': [728, 1190, 1366, 2047]},
#  'image1663120722874.png': {'crop_finger': [113, 1398, 240, 1431],
#   'crop_backhand': [890, 1337, 1123, 1572],
#   'crop_fingerbackhand': [113, 1398, 240, 1572],
#   'crop_arm': [897, 1363, 1370, 2047]},
#  'image1663635656796.png': {'crop_finger': [744, 1865, 269, 1364],
#   'crop_backhand': [769, 1168, 1079, 1469],
#   'crop_fingerbackhand': [744, 1865, 269, 1469],
#   'crop_arm': [750, 1166, 1296, 2047]},
#  'image1663635674855.png': {'crop_finger': [188, 1321, 299, 1386],
#   'crop_backhand': [899, 1292, 1112, 1493],
#   'crop_fingerbackhand': [188, 1321, 299, 1493],
#   'crop_arm': [875, 1307, 1330, 2047]},
#  'image1663635713278.png': {'crop_finger': [603, 1831, 299, 1430],
#   'crop_backhand': [666, 1081, 1137, 1550],
#   'crop_fingerbackhand': [603, 1831, 299, 1550],
#   'crop_arm': [638, 1088, 1361, 2047]},
#  'image1663635740754.png': {'crop_finger': [78, 1309, 259, 1388],
#   'crop_backhand': [848, 1258, 1083, 1489],
#   'crop_fingerbackhand': [78, 1309, 259, 1489],
#   'crop_arm': [819, 1267, 1313, 2047]},
#  'image1663635792796.png': {'crop_finger': [617, 1836, 236, 1357],
#   'crop_backhand': [680, 1077, 1062, 1466],
#   'crop_fingerbackhand': [617, 1836, 236, 1466],
#   'crop_arm': [629, 1046, 1271, 2047]},
#  'image1663635822674.png': {'crop_finger': [115, 1338, 375, 1426],
#   'crop_backhand': [918, 1301, 1107, 1514],
#   'crop_fingerbackhand': [115, 1338, 375, 1514],
#   'crop_arm': [926, 1340, 1332, 2047]},
#  'image1663635886239.png': {'crop_finger': [767, 1959, 400, 1358],
#   'crop_backhand': [794, 1180, 1057, 1457],
#   'crop_fingerbackhand': [767, 1959, 400, 1457],
#   'crop_arm': [760, 1182, 1263, 2047]},
#  'image1663635914976.png': {'crop_finger': [89, 1270, 370, 1395],
#   'crop_backhand': [851, 1242, 1085, 1479],
#   'crop_fingerbackhand': [89, 1270, 370, 1479],
#   'crop_arm': [853, 1260, 1287, 2047]},
#  'image1663635979798.png': {'crop_finger': [777, 2047, 307, 1424],
#   'crop_backhand': [803, 1211, 1110, 1520],
#   'crop_fingerbackhand': [777, 2047, 307, 1520],
#   'crop_arm': [765, 1219, 1332, 2047]},
#  'image1663636006443.png': {'crop_finger': [64, 1330, 284, 1421],
#   'crop_backhand': [857, 1276, 1133, 1537],
#   'crop_fingerbackhand': [64, 1330, 284, 1537],
#   'crop_arm': [805, 1283, 1365, 2047]},
#  ...}

# %%
crop_path = 'result/crop_info.json'
crop = utils.read_json(crop_path)

image_names = list(crop.keys())
result = defaultdict(list)

for image_name in image_names:
    crop_infos = list(crop[image_name].keys())

    for crop_info in crop_infos:
        x1, x2, y1, y2 = crop[image_name][crop_info]
        area = (x2 - x1) * (y2 - y1) / 1e6
        result[crop_info].append(area)

# %%
import matplotlib.pyplot as plt

for crop_info in crop_infos:
    plt.hist(result[crop_info], bins=50, alpha=0.5, label=crop_info)

plt.legend()
plt.xlabel('Area (mega-pixel)')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')
